# %% [markdown]
# #geopandas

# %% [markdown]
# ## Goals

# %% [markdown]
# The goal of this is to compare Above ground biomass(abg) and the RH Values from LVIS.Then for they are grouped by subplot 625 to get the data at the subplot 625 level. The ABG data come tree measurement. Then RH come from the LVIS L1 product. The is join in GIS use a spatail Join. Then they are join with the plot level data. After they are joined they are grouped Plot. The ABG is Summed if there are multiple trees. Each of the RH values are average by plot. This provieds a sum of agb and avg RH value per plot.

# %% [markdown]
# #https://lvis.gsfc.nasa.gov/workshop/LVIS_QGIS_Tutorial_Gabon.pdf

# %%
import matplotlib.pyplot 
import numpy as np
import pylab
import pandas as pd
import h5py
import geopandas as gpd
from shapely.geometry import *
from geopandas.geoseries import *

# %% [markdown]
# Bring all the data data in

# %%
# Geopandas

# %%
PLOT_RH = pd.read_csv(r'D:\Gabon_Lidar\DATA\pandas_csv\PLOT025_AGB_RH.csv')

# %%
PLOT_RH.columns
# Out:
# Index(['Subplot_25', 'AGB', 'RH10', 'RH15', 'RH20', 'RH25', 'RH30', 'RH35',
#        'RH40', 'RH45', 'RH50', 'RH55', 'RH60', 'RH65', 'RH80', 'RH70', 'RH75',
#        'RH85', 'RH90', 'RH95', 'RH96', 'RH97', 'RH99', 'RH98', 'RH100'],
#       dtype='object')

# %%
PLOT_RH.head(3)
# Out:
#    Subplot_25       AGB      RH10      RH15      RH20      RH25      RH30  \
# 0  NASA01_1.1   1938.80 -1.237407 -0.622593 -0.113519  0.450000  1.029074
# 1  NASA01_1.2   3478.87 -1.020189 -0.333396  0.253962  0.834717  1.416038
# 2  NASA01_2.1  11474.29 -1.763214 -1.365714 -1.046190 -0.770119 -0.486310
#
#        RH35      RH40      RH45  ...      RH70      RH75      RH85      RH90  \
# 0  1.721296  2.522407  3.389444  ...  6.920185  7.440000  8.484815  9.157037
# 1  2.063396  2.747170  3.491132  ...  6.504528  6.974340  7.947170  8.580755
# 2 -0.267262 -0.034524  0.245000  ...  1.867738  2.248929  3.171190  4.001310
#
#         RH95       RH96       RH97       RH99       RH98      RH100
# 0  10.087778  10.338333  10.692778  11.791111  11.127407  13.288519
# 1   9.520943   9.817170  10.183208  11.441887  10.676981  13.073019
# 2   5.304405   5.885238   6.466310   8.058810   7.107024   9.692500
#
# [3 rows x 25 columns]

# %% [markdown]
# ##### Finding AGB

# %% [markdown]
# Aboveground Biomass(AGB) is the amount of living matter above the ground. The foumulat bellow is from "Comparison of Small- and Large-Footprint Lidar Characterization of Tropical Forest Aboveground Structure and Biomass: A Case Study From Central Gabon (Silva, et al. 2018)" in it they use AGB (kg) = 0.0673 × (ρ × dbh2 × ht)0.976 they which is Chave formula (Chave , et al. 2015)

# %% [markdown]
# AGB (kg) = 0.0673 × (ρ × dbh^2 × ht)^0.976

# %% [markdown]
# were dbh is in cm, ht is in m, and ρ is the wood density in g·cm−3.
# The total AGB at plot level was then obtained by summing
# individual stem biomass estimates and converting it to Mg·ha−1.

# %% [markdown]
# Returning to out formula we need the find the ρ which is densentity. The can be found using the

# %% [markdown]
# AGB (kg) = 0.0673 × (ρ × dbh^2 × ht)^0.976
#
# were dbh is in cm, ht is in m, and ρ is the wood density in g·cm−3. The total AGB at plot level was then obtained by summing individual stem biomass estimates and converting it to Mg·ha−1.

# %% [markdown]
# The wood density came from the following two papers

# %% [markdown]
# [1] J. Chave, D. A. Coomes, S. Jansen, S. L. Lewis, N. G. Swenson,
# and A. E. Zanne, “Towards a worldwide wood economics spectrum,”
# Ecol. Lett., vol. 12, no. 4, pp. 351–366, 2009. [Online]. Available:
# https://doi.org/10.1111/j.1461-0248.2009.01285.x
# [42] A. E. Zanne et al., Data from: Towards a Worldwide Wood Economics Spectrum, Dryad Digital Repository, 2009. [Online]. Available:
# https://doi.org/10.5061/dryad.234

# %% [markdown]
# This is bringing in the would density database for the ρ

# %% [markdown]
# The would Density in data set is wsg field and it comes from the data set listed above

# %% [markdown]
# I will be going foward with 0.228 because that is the median value

# %% [markdown]
# AGB (kg) = 0.0673 × (0.228 × dbh^2 × ht)^0.976

# %% [markdown]
# the next step is to find the hieght. to find the Height I will be using the LVIS for in read that is found next to the

# %%
#LVISshot = LVIS[(LVIS.LFID == 1657455174)]

# %%
PLOT_RH
# Out:
#      Subplot_25        AGB       RH10       RH15       RH20       RH25  \
# 0    NASA01_1.1    1938.80  -1.237407  -0.622593  -0.113519   0.450000
# 1    NASA01_1.2    3478.87  -1.020189  -0.333396   0.253962   0.834717
# 2    NASA01_2.1   11474.29  -1.763214  -1.365714  -1.046190  -0.770119
# 3    NASA01_2.2    8096.01  -1.773673  -1.443469  -1.152041  -0.918980
# 4    NASA02_1.1   14658.58   2.788532   4.696789   6.175138   7.537615
# 5    NASA02_1.2   35032.13  -0.622137   0.619008   1.535878   2.285725
# 6    NASA02_2.1   32138.04   2.982386   4.768807   6.174318   7.423182
# 7    NASA02_2.2  158759.38   9.119662  11.866892  14.121419  16.168514
# 8    NASA03_1.1    3447.55  -2.009118  -0.960294  -0.209412   0.409118
# 9    NASA03_1.2    6787.85  -1.483333  -0.316667   0.617719   1.339123
# 10   NASA03_2.1   21968.06   3.151478   4.663739   5.824522   6.774957
# 11   NASA03_2.2   11584.01   1.120800   2.739333   4.120000   5.303467
# 12   NASA05_1.1   32563.70   0.820000   2.840000   5.310000   6.740000
# 13   NASA05_1.2   36579.38   0.239868   1.947947   3.986821   5.192318
# 14   NASA05_2.1    7311.63   0.820000   2.840000   5.310000   6.740000
# 15   NASA05_2.2    5804.32   0.820000   2.840000   5.310000   6.740000
# 16   NASA09_1.1     338.31  -2.651333  -2.089333  -1.624667  -1.278667
# 17   NASA09_1.2     662.19  -2.612667  -2.070667  -1.664333  -1.294667
# 18   NASA09_2.1    1698.68  -2.502500  -1.939286  -1.490000  -1.111071
# 19   NASA09_2.2     384.95  -3.329091  -2.734545  -2.250000  -1.833182
# 20   NASA10_1.1   28179.36  -0.316697   2.634587   8.670642  11.166605
# 21   NASA10_1.2    6335.06   0.448704   4.764259  13.890741  17.584444
# 22   NASA10_2.1   34640.30  -1.720000  -1.270000  -0.900000  -0.600000
# 23   NASA10_2.2   15398.45  -1.720000  -1.270000  -0.900000  -0.600000
# 24   NASA11_1.1    6819.43   0.670000   5.380000  15.400000  19.440000
# 25   NASA11_1.2    3703.87   0.670000   5.380000  15.400000  19.440000
# 26   NASA11_2.1   13050.02   0.670000   5.380000  15.400000  19.440000
# 27   NASA11_2.2    6820.67   0.670000   5.380000  15.400000  19.440000
# 28   NASA13_1.1   57295.10   9.091037  11.726000  13.828889  15.434741
# 29   NASA13_1.2   66796.56   4.434975   6.958173   9.573401  11.641168
# 30   NASA13_2.1   57641.44   2.028643   3.983107   5.628964   6.959714
# 31   NASA13_2.2   45393.00   1.643409   3.202765   4.384167   5.376098
# 32   NASA14_1.1   39044.43   5.131925   6.838261   8.025155   8.959938
# 33   NASA14_1.2   52769.88   5.531698   8.389434  10.424340  12.124811
# 34   NASA14_2.1   17627.55   3.473023   5.116419   6.291349   7.226140
# 35   NASA14_2.2   30968.92   2.560309   4.169072   5.446701   6.549381
# 36   NASA19_1.1     438.65  -1.719167  -1.323889  -1.049722  -0.793889
# 37   NASA19_1.2    2439.44  -1.427377  -1.017541  -0.708689  -0.421967
# 38   NASA19_2.1     321.41  -1.337037  -1.034444  -0.784815  -0.565926
# 39   NASA19_2.2    1898.21  -1.498169  -1.133099  -0.845634  -0.593803
# 40   NASA20_1.1   26105.66  -0.444203   0.778357   1.891159   2.859227
# 41   NASA20_1.2   36402.08  -1.469796  -0.271565   0.721497   1.565714
# 42   NASA20_2.1    3538.25  -1.667867  -1.070800  -0.550667  -0.061200
# 43   NASA20_2.2    6341.02  -1.614955  -1.058468  -0.575225  -0.148919
# 44   NASA21_1.1      83.53  -1.736000  -1.390000  -1.124000  -0.912000
# 45   NASA21_1.2     935.58  -1.752941  -1.378235  -1.141765  -0.910000
# 46   NASA21_2.1     548.62  -2.086061  -1.646364  -1.319394  -1.046061
# 47   NASA21_2.2    1072.01  -1.812368  -1.370789  -1.063421  -0.799474
# 48  NASA21A_1.1   11171.52  -0.344821   1.488393   2.833036   4.199286
# 49  NASA21A_1.2   17433.18   3.587627   5.829661   8.753898  10.107034
# 50  NASA21A_2.1   36738.97   1.131553   2.743168   4.180062   5.425155
# 51  NASA21A_2.2   47938.94   3.675227   5.999000   7.636091   9.042818
# 52   NASA22_1.1   84790.01  10.570440  12.856319  14.775879  16.212637
# 53   NASA22_1.2   44805.41   3.703810   5.505578   7.202381   8.399456
# 54   NASA22_2.1  104931.22  11.140367  14.359358  16.692064  18.207844
# 55   NASA22_2.2   30775.55   1.507692   2.735855   3.711239   4.630470
# 56   NASA23_1.1   34009.72   4.254345   5.787172   7.012138   8.178759
# 57   NASA23_1.2   56768.40   4.836686   7.381183   9.394083  11.269408
# 58   NASA23_2.1    8081.90  -2.165714  -1.607714  -1.092286  -0.678571
# 59   NASA23_2.2   10137.38  -1.050811  -0.464865   0.088649   0.670541
#
#          RH30       RH35       RH40       RH45  ...       RH70       RH75  \
# 0    1.029074   1.721296   2.522407   3.389444  ...   6.920185   7.440000
# 1    1.416038   2.063396   2.747170   3.491132  ...   6.504528   6.974340
# 2   -0.486310  -0.267262  -0.034524   0.245000  ...   1.867738   2.248929
# 3   -0.672041  -0.510612  -0.328980  -0.126327  ...   0.848980   1.126327
# 4    8.970459  10.588257  11.886605  12.948991  ...  21.052477  22.256422
# 5    2.948473   3.577634   4.185649   4.853435  ...   9.041908  10.444198
# 6    8.601705   9.840170  11.210739  12.673182  ...  19.559034  21.296591
# 7   18.243716  20.373311  22.825405  24.769189  ...  30.276689  31.746757
# 8    0.920588   1.366471   1.775588   2.147647  ...   4.097941   4.625294
# 9    1.935088   2.456667   2.937719   3.379825  ...   5.418246   5.864035
# 10   7.670435   8.498435   9.241565   9.964870  ...  14.949565  15.978435
# 11   6.335600   7.182933   7.944267   8.748000  ...  11.772000  12.613467
# 12   7.710000   8.530000   9.430000  10.780000  ...  17.900000  19.170000
# 13   6.029205   6.731987   7.496887   8.622384  ...  14.552318  15.629603
# 14   7.710000   8.530000   9.430000  10.780000  ...  17.900000  19.170000
# 15   7.710000   8.530000   9.430000  10.780000  ...  17.900000  19.170000
# 16  -0.952667  -0.624000  -0.338667  -0.053333  ...   1.532000   1.886667
# 17  -0.956000  -0.671667  -0.387667  -0.109333  ...   1.391667   1.748000
# 18  -0.766071  -0.436071  -0.095714   0.202143  ...   2.037143   2.550000
# 19  -1.458182  -1.126818  -0.810455  -0.490000  ...   0.991818   1.343636
# 20  12.253395  13.229083  14.098624  14.880092  ...  17.780826  18.377706
# 21  19.100370  20.482778  21.662963  22.707037  ...  26.088148  26.563333
# 22  -0.300000  -0.070000   0.230000   0.530000  ...   2.550000   3.370000
# 23  -0.300000  -0.070000   0.230000   0.530000  ...   2.550000   3.370000
# 24  21.080000  22.580000  23.850000  24.970000  ...  28.490000  28.930000
# 25  21.080000  22.580000  23.850000  24.970000  ...  28.490000  28.930000
# 26  21.080000  22.580000  23.850000  24.970000  ...  28.490000  28.930000
# 27  21.080000  22.580000  23.850000  24.970000  ...  28.490000  28.930000
# 28  16.827407  18.179704  19.281259  20.336000  ...  24.756444  25.452148
# 29  13.298173  15.207411  16.932284  18.474975  ...  26.006802  27.855787
# 30   8.031321   9.017643   9.991607  10.891107  ...  16.027607  17.083036
# 31   6.259545   7.228030   8.476364   9.565985  ...  13.530909  14.688371
# 32   9.766832  10.527267  11.244161  11.892733  ...  15.005652  15.821180
# 33  13.402547  14.534151  15.599811  16.605566  ...  21.059057  22.084245
# 34   8.008977   8.727163   9.384605  10.006930  ...  12.484605  12.977628
# 35   7.451031   8.265155   9.025567   9.778866  ...  13.504021  14.274227
# 36  -0.563889  -0.346944  -0.143333   0.071111  ...   1.266389   1.630556
# 37  -0.140820   0.137213   0.464098   0.864262  ...   4.217049   4.732951
# 38  -0.381481  -0.189259  -0.005556   0.194815  ...   1.455926   1.784444
# 39  -0.342817  -0.143380   0.115211   0.367746  ...   2.371831   2.968451
# 40   3.909662   5.029807   5.984976   7.159855  ...  16.085266  17.867923
# 41   2.411769   3.269184   4.754014   5.993129  ...  10.400612  11.413537
# 42   0.401333   0.900000   1.459067   2.111200  ...   6.020667   6.846267
# 43   0.250270   0.603604   0.963784   1.325225  ...   3.622072   4.304505
# 44  -0.762000  -0.598000  -0.448000  -0.298000  ...   0.422000   0.602000
# 45  -0.695882  -0.528824  -0.370000  -0.168824  ...   0.611176   0.829412
# 46  -0.782727  -0.536970  -0.309394  -0.075455  ...   1.220303   1.599091
# 47  -0.544474  -0.338947  -0.117895   0.098421  ...   1.452895   1.814737
# 48   7.306786   8.359107   9.024464   9.663929  ...  12.422321  12.965536
# 49  11.069915  11.897797  12.652119  13.304237  ...  16.842203  17.460508
# 50   6.582795   7.653416   8.752360   9.874596  ...  15.592360  16.492112
# 51  10.249727  11.292955  12.282364  13.159227  ...  16.622545  17.350000
# 52  17.369286  18.337418  19.292363  20.095000  ...  23.260110  23.878352
# 53   9.268367  10.071837  10.994966  11.742245  ...  15.938503  16.761905
# 54  19.577339  20.646560  21.540183  22.329404  ...  25.365183  25.937706
# 55   5.570855   6.526624   7.451197   8.308846  ...  12.176838  13.164701
# 56   9.464138  10.808483  12.027103  13.161517  ...  18.012276  19.030276
# 57  12.960355  14.474260  15.804970  17.034320  ...  22.541598  24.022071
# 58  -0.252286   0.181143   0.651143   1.288571  ...   5.211429   6.050286
# 59   1.344865   1.980541   2.517297   3.232432  ...  13.918108  16.675405
#
#          RH85       RH90       RH95       RH96       RH97       RH99  \
# 0    8.484815   9.157037  10.087778  10.338333  10.692778  11.791111
# 1    7.947170   8.580755   9.520943   9.817170  10.183208  11.441887
# 2    3.171190   4.001310   5.304405   5.885238   6.466310   8.058810
# 3    1.889592   2.720000   3.890612   4.191429   4.523673   5.618571
# 4   24.321927  25.447523  27.308991  27.849541  28.826697  33.211468
# 5   12.760840  14.088397  15.858168  16.407557  17.009771  18.558550
# 6   25.054489  27.029602  29.458750  30.162784  31.131932  35.346818
# 7   34.154257  35.782365  38.084595  38.645338  39.348243  41.061351
# 8    6.126471   6.993529   8.183529   8.521471   8.939706  10.341765
# 9    6.961404   7.764035   8.893333   9.195439   9.576316  10.759123
# 10  18.236087  19.718870  22.520261  23.105043  23.758522  25.603130
# 11  15.310533  16.609200  18.444800  18.884667  19.380800  20.829333
# 12  23.440000  25.160000  27.630000  28.680000  30.110000  34.150000
# 13  19.214172  20.697748  22.824040  23.711126  24.900728  28.273179
# 14  23.440000  25.160000  27.630000  28.680000  30.110000  34.150000
# 15  23.440000  25.160000  27.630000  28.680000  30.110000  34.150000
# 16   2.914667   3.772667   5.011333   5.375333   5.796667   7.291333
# 17   2.618000   3.210667   4.280333   4.719667   5.264000   6.954000
# 18   3.868214   4.850714   6.602143   7.092143   7.596071   9.441071
# 19   2.153636   2.711364   3.539545   3.796818   4.112727   5.026364
# 20  19.799266  20.593119  21.604771  21.890826  22.328624  24.881009
# 21  27.696667  28.394444  29.265185  29.500000  29.892963  31.388519
# 22   5.320000   6.290000   7.560000   7.940000   8.460000  12.950000
# 23   5.320000   6.290000   7.560000   7.940000   8.460000  12.950000
# 24  29.980000  30.650000  31.480000  31.700000  32.080000  33.270000
# 25  29.980000  30.650000  31.480000  31.700000  32.080000  33.270000
# 26  29.980000  30.650000  31.480000  31.700000  32.080000  33.270000
# 27  29.980000  30.650000  31.480000  31.700000  32.080000  33.270000
# 28  26.929704  27.853852  29.125852  29.502444  29.953630  31.393185
# 29  30.340254  31.473706  33.115330  33.543401  34.024162  35.587868
# 30  19.034214  20.197357  22.072571  22.675464  23.321571  24.827179
# 31  18.850682  20.401553  22.483712  23.131742  24.017689  27.373106
# 32  18.027081  19.132484  20.462671  20.825342  21.296522  23.319938
# 33  24.042170  25.228396  26.717453  27.196604  27.826509  29.201887
# 34  14.098651  14.850140  15.991023  16.361767  16.843814  18.517256
# 35  16.165876  17.610103  19.525258  20.037938  20.703505  22.346495
# 36   2.628889   3.380278   4.622500   4.966667   5.399167   6.553333
# 37   5.880164   7.066066   8.923279   9.288361   9.797049  11.249508
# 38   2.816296   3.477407   4.643333   4.906296   5.205926   6.049259
# 39   4.694930   5.672535   7.147042   7.567042   8.052254   9.559859
# 40  21.147053  22.691643  25.296473  26.185169  27.101981  29.001353
# 41  14.471429  16.005850  18.051497  19.136327  20.540204  23.768095
# 42   8.798000  10.329867  13.099867  13.903600  14.774267  17.078533
# 43   6.489910   7.893333  10.260721  11.138378  11.883784  14.717027
# 44   1.006000   1.290000   1.842000   2.056000   2.372000   3.150000
# 45   1.336471   1.725294   2.465882   2.786471   3.118824   4.016471
# 46   2.690606   3.426970   4.593030   4.918485   5.270606   6.271212
# 47   2.851842   3.675000   4.767632   5.065000   5.422632   6.301053
# 48  14.255000  15.071607  16.355714  16.945893  17.644464  19.400000
# 49  18.786186  19.713898  21.176864  21.589576  22.106695  24.040254
# 50  18.344658  19.269006  20.628075  20.979503  21.434348  22.743168
# 51  18.863727  19.741773  21.244409  21.559455  21.943000  23.300409
# 52  25.260275  26.130769  27.355824  27.691484  28.064560  29.238901
# 53  18.433810  19.357959  20.799796  21.260612  21.790068  23.428639
# 54  27.088028  27.767156  28.669083  28.927890  29.222890  30.178394
# 55  15.379915  16.904273  19.205427  19.684231  20.188632  21.524786
# 56  21.446207  22.604483  23.947379  24.317724  24.763379  26.176552
# 57  26.660592  28.182308  30.277278  30.757041  31.291716  32.821716
# 58   7.574000   8.404571   9.764000  10.518571  11.116286  12.892286
# 59  20.021622  22.207568  24.716486  25.122703  25.581622  26.874324
#
#          RH98      RH100
# 0   11.127407  13.288519
# 1   10.676981  13.073019
# 2    7.107024   9.692500
# 3    4.927347   7.015510
# 4   31.949908  35.157431
# 5   17.668931  20.193130
# 6   33.376648  37.745057
# 7   40.150338  42.638041
# 8    9.487647  12.424412
# 9   10.051404  12.422105
# 10  24.516000  27.658957
# 11  20.002533  22.468800
# 12  32.280000  37.600000
# 13  26.699205  31.246358
# 14  32.280000  37.600000
# 15  32.280000  37.600000
# 16   6.381333   9.218000
# 17   5.904333   8.994333
# 18   8.267857  11.346429
# 19   4.514091   6.345909
# 20  23.144312  27.612661
# 21  30.417222  33.281111
# 22   9.810000  17.220000
# 23   9.810000  17.220000
# 24  32.520000  34.920000
# 25  32.520000  34.920000
# 26  32.520000  34.920000
# 27  32.520000  34.920000
# 28  30.533185  33.442815
# 29  34.625685  37.457005
# 30  23.921429  27.092857
# 31  25.251667  30.172045
# 32  22.010000  25.246770
# 33  28.426509  30.698302
# 34  17.511349  20.326372
# 35  21.420928  24.391753
# 36   5.899444   7.838333
# 37  10.471639  13.073443
# 38   5.556296   7.302593
# 39   8.627324  11.100423
# 40  27.993527  30.929710
# 41  22.078980  26.117483
# 42  15.772800  19.636933
# 43  12.805856  17.560811
# 44   2.730000   3.852000
# 45   3.528235   4.703529
# 46   5.710303   7.399697
# 47   5.829737   6.926053
# 48  18.522679  20.740179
# 49  22.856441  26.231610
# 50  22.003292  24.236398
# 51  22.492364  24.788182
# 52  28.543846  30.776264
# 53  22.506531  25.090544
# 54  29.604725  31.726789
# 55  20.762949  23.015214
# 56  25.348414  28.351172
# 57  31.936509  34.632663
# 58  11.778286  15.305714
# 59  26.123243  28.543243
#
# [60 rows x 25 columns]

# %% [markdown]
# #matplotlib.pyplot.scatter(LVIS_in_subplots13_22.GLON,LVIS_in_subplots13_22.ZG,color='r')
# matplotlib.pyplot.scatter(LVIS_in_subplots13_22.GLON,LVIS_in_subplots13_22.RH25,color='orange')
# matplotlib.pyplot.scatter(LVIS_in_subplots13_22.GLON,LVIS_in_subplots13_22.RH50,color='y')
# matplotlib.pyplot.scatter(LVIS_in_subplots13_22.GLON,LVIS_in_subplots13_22.RH75,color='g')
# #matplotlib.pyplot.scatter(LVIS_in_subplots13_22.GLON,LVIS_in_subplots13_22.ZT,color='b')
# matplotlib.pyplot.show()

# %% [markdown]
# AGB (kg) = 0.0673 × (ρ × dbh^2 × ht)^0.976

# %%
#https://automating-gis-processes.github.io/2017/lessons/L3/nearest-neighbour.html

# %%
#Trees_in_subplots13_22csv = Trees_in_subplots13_22.to_csv(r'D:\Gabon_Lidar\DATA\pandas_csv\Trees_in_subplots13_22.csv')

# %%
#LVIS_in_subplots13_22csv = LVIS_in_subplots13_22.to_csv(r'D:\Gabon_Lidar\DATA\pandas_csv\LVIS_in_subplots13_22.csv')

# %%
#Trees_in_subplots13_22 = pd.read_csv (r'D:\Gabon_Lidar\DATA\pandas_csv\Trees_in_subplots13_22.csv')

# %%
#LVIS_in_subplots13_22 = pd.read_csv (r'D:\Gabon_Lidar\DATA\pandas_csv\LVIS_in_subplots13_22.csv')

# %%
#https://www.listendata.com/2019/07/how-to-filter-pandas-dataframe.html#:~:text=%20Filter%20pandas%20dataframe%20by%20column%20value%20,same%20output.%20It%27s%20just%20a%20different...%20More%20

# %%
PLOT_RH.columns
# Out:
# Index(['Subplot_25', 'AGB', 'RH10', 'RH15', 'RH20', 'RH25', 'RH30', 'RH35',
#        'RH40', 'RH45', 'RH50', 'RH55', 'RH60', 'RH65', 'RH80', 'RH70', 'RH75',
#        'RH85', 'RH90', 'RH95', 'RH96', 'RH97', 'RH99', 'RH98', 'RH100'],
#       dtype='object')

# %%
#TreesRH13_22.columns

# %%
#matplotlib.pyplot.scatter(Trees_RH.m_agb,Trees_RH.ZG,color='r') 
matplotlib.pyplot.scatter(PLOT_RH.AGB,PLOT_RH.RH25,color='orange') 
matplotlib.pyplot.scatter(PLOT_RH.AGB,PLOT_RH.RH50,color='y')
matplotlib.pyplot.scatter(PLOT_RH.AGB,PLOT_RH.RH75,color='g')
matplotlib.pyplot.scatter(PLOT_RH.AGB,PLOT_RH.RH100,color='b')
matplotlib.pyplot.show()

# %%
matplotlib.pyplot.scatter(PLOT_RH.AGB,PLOT_RH.RH25,color='orange')

# %%
matplotlib.pyplot.scatter(PLOT_RH.AGB,PLOT_RH.RH50,color='y')

# %%
matplotlib.pyplot.scatter(PLOT_RH.AGB,PLOT_RH.RH75,color='g')

# %%
matplotlib.pyplot.scatter(PLOT_RH.AGB,PLOT_RH.RH100,color='b')
