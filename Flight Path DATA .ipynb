# %% [markdown]
# # Flight Path DATA

# %% [markdown]
# In order to find the L1B and the L2 data corapsoneds with the study sites use of the flight path data is needed. Over laying the flight paths with the study sites provide a date to such for. With most of the data over study sites come March 03 2016 will be the data pulled from the web.

# %% [markdown]
# ## DATA

# %% [markdown]
# The Flight data are KML or shapefiles that show the flight path of a given flight where data what was collected.

# %% [markdown]
# https://lvis.gsfc.nasa.gov/Data/Maps/Gabon2016Map.html

# %% [markdown]
# ## Processing

# %% [markdown]
# In order to find the L1 and L2 file that are need to be download we need to know which flights has that data. This is done by first importing tree plot information into the mapping software(Arc Pro) and flight path information.

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# After bring the those data set it import to sperate the flight information by data. Not all the flight will flight over the study sites.

# %%
img2

# %%
For this project the study sites are found to fall on March 8rd 2016.

# %%
img3

# %% [markdown]
# Know that the data need for our study site is on 0308 can be use to filter for data that my fall with in our study sites. Download the Level2 first and check for what data files line up with the study plots.

# %%
img4

# %% [markdown]
# After the text file are downloaded the dataset need to be processed into a csv file. The method used to process the text file into a csv can be found her on page 6 of this tutorial. (https://lvis.gsfc.nasa.gov/workshop/LVIS_QGIS_Tutorial_Gabon.pdf)

# %%
One the csv of the L2 data is created it can be found
