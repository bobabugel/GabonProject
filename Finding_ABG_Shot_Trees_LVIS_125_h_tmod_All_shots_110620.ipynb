# %% [markdown]
# #geopandas

# %% [markdown]
# #https://lvis.gsfc.nasa.gov/workshop/LVIS_QGIS_Tutorial_Gabon.pdf

# %%
import matplotlib.pyplot 
import numpy as np
import pylab
import pandas as pd
import h5py
import geopandas as gpd
from shapely.geometry import *
from geopandas.geoseries import *
from geopandas import GeoDataFrame
from shapely.geometry import Point
import fiona
import seaborn as sns

# %% [markdown]
# Bring all the data data in

# %%
# Geopandas

# %%
#Trees

# %%
# This convert a csv to a shpage file

# %%
df = pd.read_csv('D:\Gabon_Lidar\DATA\pandas_csv\Mondah_Field_Data_Trees.csv')

geometry = [Point(xy) for xy in zip(df.x, df.y)]
crs = {'init': 'epsg:4326'} #http://www.spatialreference.org/ref/epsg/2263/
geo_df = GeoDataFrame(df, crs=crs, geometry=geometry)

geo_df.to_file(driver='ESRI Shapefile', filename='D:\Gabon_Lidar\DATA\shp\Mondah_Field_Data_Trees.shp')
# Out:
# C:\Users\17183\anaconda3\envs\G_H_GEDI\lib\site-packages\pyproj\crs\crs.py:53: FutureWarning: '+init=<authority>:<code>' syntax is deprecated. '<authority>:<code>' is the preferred initialization method. When making the change, be mindful of axis order changes: https://pyproj4.github.io/pyproj/stable/gotchas.html#axis-order-changes-in-proj-6
#   return _prepare_from_string(" ".join(pjargs))

# %%
#Trees

# %%
Trees = gpd.read_file(r'D:\Gabon_Lidar\DATA\shp\Mondah_Field_Data_Trees_in_study_site_lat_lon_a.shp')

# %%
Trees.plot()
# Out:
# <AxesSubplot:>

# %%
Trees = Trees.to_crs(epsg=4326)

# %%
Trees
# Out:
#         plot  subplot   tree_date           family                species  \
# 0     NASA01        1  2016-02-03    Euphorbiaceae          Macaranga sp.
# 1     NASA01        1  2016-02-03    Euphorbiaceae          Macaranga sp.
# 2     NASA01        1  2016-02-03    Euphorbiaceae          Macaranga sp.
# 3     NASA01        1  2016-02-03    Euphorbiaceae          Macaranga sp.
# 4     NASA01        1  2016-02-03    Euphorbiaceae          Macaranga sp.
# ...      ...      ...         ...              ...                    ...
# 6627  NASA23       14  2016-02-21               NA                     NA
# 6628  NASA23       14  2016-02-21               NA                     NA
# 6629  NASA23       14  2016-02-21    Myristicaceae  Pycnanthus angolensis
# 6630  NASA23       14  2016-02-21  Melastomataceae     Dichaetanthera sp.
# 6631  NASA23       14  2016-02-21               NA                     NA
#
#            wsg  tree  stem   epsg            x  ...    a_stem     h_t  \
# ...

# %%
Trees.columns
# Out:
# Index(['plot', 'subplot', 'tree_date', 'family', 'species', 'wsg', 'tree',
#        'stem', 'epsg', 'x', 'y', 'status', 'allom_key', 'a_stem', 'h_t',
#        'h_t_mod', 'd_stem', 'd_stem_val', 'd_ht', 'm_agb', 'POINT_X',
#        'POINT_Y', 'geometry'],
#       dtype='object')

# %%
Trees.head(3)
# Out:
#      plot  subplot   tree_date         family        species       wsg  tree  \
# 0  NASA01        1  2016-02-03  Euphorbiaceae  Macaranga sp.  0.381789  6501
# 1  NASA01        1  2016-02-03  Euphorbiaceae  Macaranga sp.  0.381789  6502
# 2  NASA01        1  2016-02-03  Euphorbiaceae  Macaranga sp.  0.381789  6503
#
#    stem   epsg            x  ...    a_stem     h_t  h_t_mod  d_stem  \
# 0     1  32632  535829.6805  ...  0.011120 -9999.0    12.18   0.119
# 1     1  32632  535827.8529  ...  0.008171 -9999.0    11.28   0.102
# 2     1  32632  535829.8895  ...  0.009331 -9999.0    11.66   0.109
#
#    d_stem_val  d_ht  m_agb   POINT_X   POINT_Y                 geometry
# 0           1  1.65  37.92  9.322006  0.554795  POINT (9.32201 0.55479)
# 1           1  1.30  26.05  9.321989  0.554836  POINT (9.32199 0.55484)
# 2           1  1.30  30.62  9.322007  0.554844  POINT (9.32201 0.55484)
#
# [3 rows x 23 columns]

# %% [markdown]
# Selecting Tree with a measured height.

# %%
# List of plots  01,02,03,05,09,10,11,13,14,19,21,21A,22,23
# I think plot19 has problem with it's sample

# %%
#Trees = Trees[(Trees['plot'] == 'NASA14')]

# %%
#NOTE: 0nly 121 trees have h_t measurements

# %%
#Trees = Trees[(Trees['h_t'] > 0)]

# %%
Trees = Trees[(Trees['h_t_mod'] > 0)]

# %%
Trees
# Out:
#         plot  subplot   tree_date           family                species  \
# 0     NASA01        1  2016-02-03    Euphorbiaceae          Macaranga sp.
# 1     NASA01        1  2016-02-03    Euphorbiaceae          Macaranga sp.
# 2     NASA01        1  2016-02-03    Euphorbiaceae          Macaranga sp.
# 3     NASA01        1  2016-02-03    Euphorbiaceae          Macaranga sp.
# 4     NASA01        1  2016-02-03    Euphorbiaceae          Macaranga sp.
# ...      ...      ...         ...              ...                    ...
# 6627  NASA23       14  2016-02-21               NA                     NA
# 6628  NASA23       14  2016-02-21               NA                     NA
# 6629  NASA23       14  2016-02-21    Myristicaceae  Pycnanthus angolensis
# 6630  NASA23       14  2016-02-21  Melastomataceae     Dichaetanthera sp.
# 6631  NASA23       14  2016-02-21               NA                     NA
#
#            wsg  tree  stem   epsg            x  ...    a_stem     h_t  \
# ...

# %%
Trees['tree_count'] = 1

# %%
Trees
# Out:
#         plot  subplot   tree_date           family                species  \
# 0     NASA01        1  2016-02-03    Euphorbiaceae          Macaranga sp.
# 1     NASA01        1  2016-02-03    Euphorbiaceae          Macaranga sp.
# 2     NASA01        1  2016-02-03    Euphorbiaceae          Macaranga sp.
# 3     NASA01        1  2016-02-03    Euphorbiaceae          Macaranga sp.
# 4     NASA01        1  2016-02-03    Euphorbiaceae          Macaranga sp.
# ...      ...      ...         ...              ...                    ...
# 6627  NASA23       14  2016-02-21               NA                     NA
# 6628  NASA23       14  2016-02-21               NA                     NA
# 6629  NASA23       14  2016-02-21    Myristicaceae  Pycnanthus angolensis
# 6630  NASA23       14  2016-02-21  Melastomataceae     Dichaetanthera sp.
# 6631  NASA23       14  2016-02-21               NA                     NA
#
#            wsg  tree  stem   epsg            x  ...     h_t  h_t_mod  d_stem  \
# ...

# %%
Trees.plot()
# Out:
# <AxesSubplot:>

# %%
#LVIS9421011 = LVISpoints[(LVISpoints.SHOTNUMBER == 9421011)]

# %%
#LVIS

# %%
#LVIS = gpd.read_file(r'D:\Gabon_Lidar\DATA\shp\LVIS2_Gabon2016_0308_R1808_studyarea.shp')

# %%
#These were buffered in arc pro

# %%
#LVIS = gpd.read_file(r'D:\Gabon_Lidar\DATA\shp\LVIS2_Gabon2016_0308_R1808_studyarea.shp')

# %%
#LVIS_5m = gpd.read_file(r'D:\Gabon_Lidar\DATA\shp\LVIS2_Gabon2016_5m.shp')

# %%
#LVIS_10m = gpd.read_file(r'D:\Gabon_Lidar\DATA\shp\LVIS2_Gabon2016_10m.shp')

# %%
LVIS_5m = gpd.read_file(r'D:\Gabon_Lidar\DATA\shp\LVIS2_Gabon2016_125m.shp')

# %%
LVIS_5m
# Out:
#            LFID  SHOTNUMBER       TIME      GLON      GLAT     ZG  HLON  HLAT  \
# 0    1657455174    11689486  48006.889  9.422888  0.617327  17.89  -999  -999
# 1    1657455174    11689489  48006.892  9.422886  0.617044  17.57  -999  -999
# 2    1657455174    11689490  48006.893  9.422886  0.616949  17.68  -999  -999
# 3    1657455174    11689493  48006.896  9.422884  0.616666  17.46  -999  -999
# 4    1657455174    11689494  48006.897  9.422884  0.616572  17.47  -999  -999
# ..          ...         ...        ...       ...       ...    ...   ...   ...
# 823  1657455148     9911421  46228.812  9.330292  0.546591  25.30  -999  -999
# 824  1657455148     9911422  46228.813  9.330293  0.546496  24.39  -999  -999
# 825  1657455148     9911424  46228.815  9.330295  0.546308  26.94  -999  -999
# 826  1657455148     9911425  46228.816  9.330296  0.546213  24.59  -999  -999
# 827  1657455148     9911426  46228.817  9.330297  0.546119  25.45  -999  -999
#
# ...

# %%
#Changing CRS 
LVIS_5m= LVIS_5m.to_crs(epsg=4326)

# %%
#LVIS = LVIS[(LVIS.SHOTNUMBER == 11689486)]

# %%
LVIS_5m.head()
# Out:
#          LFID  SHOTNUMBER       TIME      GLON      GLAT     ZG  HLON  HLAT  \
# 0  1657455174    11689486  48006.889  9.422888  0.617327  17.89  -999  -999
# 1  1657455174    11689489  48006.892  9.422886  0.617044  17.57  -999  -999
# 2  1657455174    11689490  48006.893  9.422886  0.616949  17.68  -999  -999
# 3  1657455174    11689493  48006.896  9.422884  0.616666  17.46  -999  -999
# 4  1657455174    11689494  48006.897  9.422884  0.616572  17.47  -999  -999
#
#     ZH      TLON  ...  CHANNEL_L1  CHANNEL_ZG  CHANNEL_RH   POINT_X   POINT_Y  \
# 0 -999  9.422889  ...           1           1           1  9.422888  0.617327
# 1 -999  9.422886  ...           1           1           1  9.422886  0.617044
# 2 -999  9.422886  ...           1           1           1  9.422886  0.616949
# 3 -999  9.422884  ...           1           1           1  9.422884  0.616666
# 4 -999  9.422884  ...           1           1           1  9.422884  0.616572
#
# ...

# %%
LVIS_5m.plot()
# Out:
# <AxesSubplot:>

# %%
Trees
# Out:
#         plot  subplot   tree_date           family                species  \
# 0     NASA01        1  2016-02-03    Euphorbiaceae          Macaranga sp.
# 1     NASA01        1  2016-02-03    Euphorbiaceae          Macaranga sp.
# 2     NASA01        1  2016-02-03    Euphorbiaceae          Macaranga sp.
# 3     NASA01        1  2016-02-03    Euphorbiaceae          Macaranga sp.
# 4     NASA01        1  2016-02-03    Euphorbiaceae          Macaranga sp.
# ...      ...      ...         ...              ...                    ...
# 6627  NASA23       14  2016-02-21               NA                     NA
# 6628  NASA23       14  2016-02-21               NA                     NA
# 6629  NASA23       14  2016-02-21    Myristicaceae  Pycnanthus angolensis
# 6630  NASA23       14  2016-02-21  Melastomataceae     Dichaetanthera sp.
# 6631  NASA23       14  2016-02-21               NA                     NA
#
#            wsg  tree  stem   epsg            x  ...     h_t  h_t_mod  d_stem  \
# ...

# %%
Trees_LVIS_5m = gpd.overlay(Trees,LVIS_5m, how = 'intersection')

# %%
Trees_LVIS_5m
# Out:
#          plot  subplot   tree_date           family             species  \
# 0      NASA01        1  2016-02-03    Euphorbiaceae       Macaranga sp.
# 1      NASA01        1  2016-02-03    Euphorbiaceae       Macaranga sp.
# 2      NASA01        1  2016-02-03    Euphorbiaceae       Macaranga sp.
# 3      NASA01        1  2016-02-03    Euphorbiaceae       Macaranga sp.
# 4      NASA01        1  2016-02-03    Euphorbiaceae       Macaranga sp.
# ...       ...      ...         ...              ...                 ...
# 16841  NASA23       14  2016-02-21  Melastomataceae  Dichaetanthera sp.
# 16842  NASA23       14  2016-02-21               NA                  NA
# 16843  NASA23       14  2016-02-21      Burseraceae  Aucoumea klaineana
# 16844  NASA23       14  2016-02-21  Melastomataceae  Dichaetanthera sp.
# 16845  NASA23       14  2016-02-21               NA                  NA
#
#             wsg  tree  stem   epsg            x  ...  CHANNEL_L1  CHANNEL_ZG  \
# ...

# %%
Trees_LVIS_5m.columns
# Out:
# Index(['plot', 'subplot', 'tree_date', 'family', 'species', 'wsg', 'tree',
#        'stem', 'epsg', 'x', 'y', 'status', 'allom_key', 'a_stem', 'h_t',
#        'h_t_mod', 'd_stem', 'd_stem_val', 'd_ht', 'm_agb', 'POINT_X_1',
#        'POINT_Y_1', 'tree_count', 'LFID', 'SHOTNUMBER', 'TIME', 'GLON', 'GLAT',
#        'ZG', 'HLON', 'HLAT', 'ZH', 'TLON', 'TLAT', 'ZT', 'RH10', 'RH15',
#        'RH20', 'RH25', 'RH30', 'RH35', 'RH40', 'RH45', 'RH50', 'RH55', 'RH60',
#        'RH65', 'RH70', 'RH75', 'RH80', 'RH85', 'RH90', 'RH95', 'RH96', 'RH97',
#        'RH98', 'RH99', 'RH100', 'AZIMUTH', 'INCIDENTAN', 'RANGE', 'COMPLEXITY',
#        'CHANNEL_L1', 'CHANNEL_ZG', 'CHANNEL_RH', 'POINT_X_2', 'POINT_Y_2',
#        'BUFF_DIST', 'ORIG_FID', 'Shape_Leng', 'Shape_Area', 'geometry'],
#       dtype='object')

# %%
#SUM

# %%
sum = ['SHOTNUMBER', 'm_agb','h_t_mod','tree_count']

# %%
Trees_RH_sum= Trees_LVIS_5m[sum]

# %%
Trees_RH_sum.head()
# Out:
#    SHOTNUMBER  m_agb  h_t_mod  tree_count
# 0     9902820  37.92    12.18           1
# 1     9902820  26.05    11.28           1
# 2     9902820  30.62    11.66           1
# 3     9902820  41.10    12.38           1
# 4     9902820  30.62    11.66           1

# %%
##Creat height ^2

# %%
Trees_RH_sum['h_t_sq_sum'] = Trees_RH_sum['h_t_mod']**2
# Out:
# <ipython-input-44-e2532609cf72>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   Trees_RH_sum['h_t_sq_sum'] = Trees_RH_sum['h_t_mod']**2

# %%
Trees_RH_sum
# Out:
#        SHOTNUMBER   m_agb  h_t_mod  tree_count  h_t_sq_sum
# 0         9902820   37.92    12.18           1    148.3524
# 1         9902820   26.05    11.28           1    127.2384
# 2         9902820   30.62    11.66           1    135.9556
# 3         9902820   41.10    12.38           1    153.2644
# 4         9902820   30.62    11.66           1    135.9556
# ...           ...     ...      ...         ...         ...
# 16841     9897120   52.77    11.87           1    140.8969
# 16842     9897120  640.25    20.24           1    409.6576
# 16843     9897121   37.54    12.18           1    148.3524
# 16844     9897121   52.77    11.87           1    140.8969
# 16845     9897095  640.25    20.24           1    409.6576
#
# [16846 rows x 5 columns]

# %%
Trees_RH_sum_5m = Trees_RH_sum.groupby(by='SHOTNUMBER').sum()

# %%
Trees_RH_sum_5m
# Out:
#               m_agb  h_t_mod  tree_count  h_t_sq_sum
# SHOTNUMBER
# 9361768     1905.25   441.85          37   5419.7895
# 9361769     1664.24   390.40          33   4735.7346
# 9361773     2181.50   168.20          11   2658.3336
# 9361774     1864.96   126.64           8   2051.2062
# 9361775      455.09    44.19           3    661.6905
# ...             ...      ...         ...         ...
# 11690161     148.91    34.21           3    402.5899
# 11690162     437.38    86.01           7   1063.4421
# 11690205     424.60    85.52           7   1051.2656
# 11690206     379.27    82.37           7    984.4541
# 11690207      13.49     9.03           1     81.5409
#
# [776 rows x 4 columns]

# %%
Trees_RH_sum_5m
# Out:
#               m_agb  h_t_mod  tree_count  h_t_sq_sum
# SHOTNUMBER
# 9361768     1905.25   441.85          37   5419.7895
# 9361769     1664.24   390.40          33   4735.7346
# 9361773     2181.50   168.20          11   2658.3336
# 9361774     1864.96   126.64           8   2051.2062
# 9361775      455.09    44.19           3    661.6905
# ...             ...      ...         ...         ...
# 11690161     148.91    34.21           3    402.5899
# 11690162     437.38    86.01           7   1063.4421
# 11690205     424.60    85.52           7   1051.2656
# 11690206     379.27    82.37           7    984.4541
# 11690207      13.49     9.03           1     81.5409
#
# [776 rows x 4 columns]

# %%
Trees_RH_sum_5m.to_csv(r'D:\Gabon_Lidar\DATA\pandas_csv\Trees_RH_sum_5m.csv')

# %%
Trees_RH_sum_5m =pd.read_csv(r'D:\Gabon_Lidar\DATA\pandas_csv\Trees_RH_sum_5m.csv')

# %%
Trees_RH_sum_5m
# Out:
#      SHOTNUMBER    m_agb  h_t_mod  tree_count  h_t_sq_sum
# 0       9361768  1905.25   441.85          37   5419.7895
# 1       9361769  1664.24   390.40          33   4735.7346
# 2       9361773  2181.50   168.20          11   2658.3336
# 3       9361774  1864.96   126.64           8   2051.2062
# 4       9361775   455.09    44.19           3    661.6905
# ..          ...      ...      ...         ...         ...
# 771    11690161   148.91    34.21           3    402.5899
# 772    11690162   437.38    86.01           7   1063.4421
# 773    11690205   424.60    85.52           7   1051.2656
# 774    11690206   379.27    82.37           7    984.4541
# 775    11690207    13.49     9.03           1     81.5409
#
# [776 rows x 5 columns]

# %%
Trees_RH_sum_5m.columns = ['SHOTNUMBER', 'm_agb','h_t_modsum','tree_count','h_t_mod_sq_sum']

# %%
Trees_RH_sum_5m
# Out:
#      SHOTNUMBER    m_agb  h_t_modsum  tree_count  h_t_mod_sq_sum
# 0       9361768  1905.25      441.85          37       5419.7895
# 1       9361769  1664.24      390.40          33       4735.7346
# 2       9361773  2181.50      168.20          11       2658.3336
# 3       9361774  1864.96      126.64           8       2051.2062
# 4       9361775   455.09       44.19           3        661.6905
# ..          ...      ...         ...         ...             ...
# 771    11690161   148.91       34.21           3        402.5899
# 772    11690162   437.38       86.01           7       1063.4421
# 773    11690205   424.60       85.52           7       1051.2656
# 774    11690206   379.27       82.37           7        984.4541
# 775    11690207    13.49        9.03           1         81.5409
#
# [776 rows x 5 columns]

# %%
#MEAN

# %%
mean = ['SHOTNUMBER','h_t_mod']

# %%
Trees_RH_Shot_5mean = Trees_LVIS_5m[mean]

# %%
Trees_RH_Shot_5mean = Trees_RH_Shot_5mean.groupby(by='SHOTNUMBER').mean()

# %%
Trees_RH_Shot_5mean.to_csv(r'D:\Gabon_Lidar\DATA\pandas_csv\Trees_RH_Shot_5mean.csv')

# %%
Trees_RH_Shot_5mean =pd.read_csv(r'D:\Gabon_Lidar\DATA\pandas_csv\Trees_RH_Shot_5mean.csv')

# %%
Trees_RH_Shot_5mean
# Out:
#      SHOTNUMBER    h_t_mod
# 0       9361768  11.941892
# 1       9361769  11.830303
# 2       9361773  15.290909
# 3       9361774  15.830000
# 4       9361775  14.730000
# ..          ...        ...
# 771    11690161  11.403333
# 772    11690162  12.287143
# 773    11690205  12.217143
# 774    11690206  11.767143
# 775    11690207   9.030000
#
# [776 rows x 2 columns]

# %%
Trees_RH_Shot_5mean.columns = ['SHOTNUMBER','h_t_modmean']

# %%
Trees_RH_Shot_5mean
# Out:
#      SHOTNUMBER  h_t_modmean
# 0       9361768    11.941892
# 1       9361769    11.830303
# 2       9361773    15.290909
# 3       9361774    15.830000
# 4       9361775    14.730000
# ..          ...          ...
# 771    11690161    11.403333
# 772    11690162    12.287143
# 773    11690205    12.217143
# 774    11690206    11.767143
# 775    11690207     9.030000
#
# [776 rows x 2 columns]

# %%
#MAX

# %%
#Trees_LVIS_5m

# %%
Trees_LVIS_5m
# Out:
#          plot  subplot   tree_date           family             species  \
# 0      NASA01        1  2016-02-03    Euphorbiaceae       Macaranga sp.
# 1      NASA01        1  2016-02-03    Euphorbiaceae       Macaranga sp.
# 2      NASA01        1  2016-02-03    Euphorbiaceae       Macaranga sp.
# 3      NASA01        1  2016-02-03    Euphorbiaceae       Macaranga sp.
# 4      NASA01        1  2016-02-03    Euphorbiaceae       Macaranga sp.
# ...       ...      ...         ...              ...                 ...
# 16841  NASA23       14  2016-02-21  Melastomataceae  Dichaetanthera sp.
# 16842  NASA23       14  2016-02-21               NA                  NA
# 16843  NASA23       14  2016-02-21      Burseraceae  Aucoumea klaineana
# 16844  NASA23       14  2016-02-21  Melastomataceae  Dichaetanthera sp.
# 16845  NASA23       14  2016-02-21               NA                  NA
#
#             wsg  tree  stem   epsg            x  ...  CHANNEL_L1  CHANNEL_ZG  \
# ...

# %%
max = ['SHOTNUMBER','RH10',
       'RH15', 'RH20', 'RH25', 'RH30', 'RH35', 'RH40', 'RH45', 'RH50', 'RH55',
       'RH60', 'RH65', 'RH70', 'RH75', 'RH80', 'RH85', 'RH90', 'RH95', 'RH96',
       'RH97', 'RH98', 'RH99', 'RH100','h_t_mod']

# %%
Trees_RH_Shot_5max = Trees_LVIS_5m[max]

# %%
Trees_RH_Shot_5max = Trees_RH_Shot_5max.groupby(by='SHOTNUMBER').max()

# %%
Trees_RH_Shot_5max
# Out:
#             RH10  RH15  RH20  RH25   RH30   RH35   RH40   RH45   RH50   RH55  \
# SHOTNUMBER
# 9361768     5.46  7.34  8.53  9.43  10.11  10.70  11.30  11.98  12.73  13.47
# 9361769     3.60  5.39  6.37  7.04   7.57   8.09   8.61   9.06   9.51   9.96
# 9361773    -1.28 -0.83 -0.45 -0.08   0.30   0.67   1.12   1.79   2.77   3.67
# 9361774    -1.42 -1.05 -0.75 -0.52  -0.30  -0.08   0.15   0.37   0.60   0.90
# 9361775    -1.09 -0.87 -0.64 -0.49  -0.27  -0.12   0.11   0.26   0.48   0.63
# ...          ...   ...   ...   ...    ...    ...    ...    ...    ...    ...
# 11690161   -1.80 -1.42 -1.20 -0.97  -0.75  -0.60  -0.45  -0.30  -0.15   0.00
# 11690162   -1.80 -1.43 -1.20 -0.98  -0.75  -0.60  -0.45  -0.30  -0.15  -0.08
# 11690205   -1.72 -1.35 -1.13 -0.90  -0.68  -0.53  -0.38  -0.15  -0.00   0.15
# 11690206   -1.80 -1.43 -1.13 -0.90  -0.75  -0.53  -0.38  -0.23  -0.08   0.07
# 11690207   -1.79 -1.50 -1.20 -0.97  -0.82  -0.67  -0.52  -0.37  -0.22  -0.07
#
# ...

# %%
Trees_RH_Shot_5max.to_csv(r'D:\Gabon_Lidar\DATA\pandas_csv\Trees_RH_Shot_5max.csv')

# %%
Trees_RH_Shot_5max =pd.read_csv(r'D:\Gabon_Lidar\DATA\pandas_csv\Trees_RH_Shot_5max.csv')

# %%
Trees_RH_Shot_5max.columns = ['SHOTNUMBER','RH10',
       'RH15', 'RH20', 'RH25', 'RH30', 'RH35', 'RH40', 'RH45', 'RH50', 'RH55',
       'RH60', 'RH65', 'RH70', 'RH75', 'RH80', 'RH85', 'RH90', 'RH95', 'RH96',
       'RH97', 'RH98', 'RH99', 'RH100','h_t_modmax']

# %%
Trees_RH_Shot_5max.head()
# Out:
#    SHOTNUMBER  RH10  RH15  RH20  RH25   RH30   RH35   RH40   RH45   RH50  ...  \
# 0     9361768  5.46  7.34  8.53  9.43  10.11  10.70  11.30  11.98  12.73  ...
# 1     9361769  3.60  5.39  6.37  7.04   7.57   8.09   8.61   9.06   9.51  ...
# 2     9361773 -1.28 -0.83 -0.45 -0.08   0.30   0.67   1.12   1.79   2.77  ...
# 3     9361774 -1.42 -1.05 -0.75 -0.52  -0.30  -0.08   0.15   0.37   0.60  ...
# 4     9361775 -1.09 -0.87 -0.64 -0.49  -0.27  -0.12   0.11   0.26   0.48  ...
#
#     RH80   RH85   RH90   RH95   RH96   RH97   RH98   RH99  RH100  h_t_modmax
# 0  16.77  17.52  18.41  19.54  19.84  20.14  20.51  21.03  22.08       16.43
# 1  11.83  12.28  12.88  13.85  14.23  14.68  15.43  16.62  19.24       16.32
# 2   8.38   9.58  10.85  13.92  14.90  16.10  17.59  19.02  20.96       19.06
# 3   5.62   7.11   8.39   9.96  10.33  10.86  11.53  12.88  15.20       19.06
# 4   3.63   4.83   6.25   8.94  11.04  17.33  20.25  23.02  25.35       17.38
#
# [5 rows x 25 columns]

# %%
#Join Sum and MAX

# %%
 Trees_RH_Shot_5 = Trees_RH_Shot_5max.set_index('SHOTNUMBER').join( Trees_RH_sum_5m.set_index('SHOTNUMBER'))

# %%
 Trees_RH_Shot_5.to_csv(r'D:\Gabon_Lidar\DATA\pandas_csv\Trees_RH_Shot_5.csv')

# %%
 Trees_RH_Shot_5 =pd.read_csv(r'D:\Gabon_Lidar\DATA\pandas_csv\Trees_RH_Shot_5.csv')

# %%
 Trees_RH_Shot_5.columns
# Out:
# Index(['SHOTNUMBER', 'RH10', 'RH15', 'RH20', 'RH25', 'RH30', 'RH35', 'RH40',
#        'RH45', 'RH50', 'RH55', 'RH60', 'RH65', 'RH70', 'RH75', 'RH80', 'RH85',
#        'RH90', 'RH95', 'RH96', 'RH97', 'RH98', 'RH99', 'RH100', 'h_t_modmax',
#        'm_agb', 'h_t_modsum', 'tree_count', 'h_t_mod_sq_sum'],
#       dtype='object')

# %%
#Join MEAN

# %%
 Trees_RH_Shot_5 = Trees_RH_Shot_5.set_index('SHOTNUMBER').join(Trees_RH_Shot_5mean.set_index('SHOTNUMBER'))

# %%
 Trees_RH_Shot_5
# Out:
#             RH10  RH15  RH20  RH25   RH30   RH35   RH40   RH45   RH50   RH55  \
# SHOTNUMBER
# 9361768     5.46  7.34  8.53  9.43  10.11  10.70  11.30  11.98  12.73  13.47
# 9361769     3.60  5.39  6.37  7.04   7.57   8.09   8.61   9.06   9.51   9.96
# 9361773    -1.28 -0.83 -0.45 -0.08   0.30   0.67   1.12   1.79   2.77   3.67
# 9361774    -1.42 -1.05 -0.75 -0.52  -0.30  -0.08   0.15   0.37   0.60   0.90
# 9361775    -1.09 -0.87 -0.64 -0.49  -0.27  -0.12   0.11   0.26   0.48   0.63
# ...          ...   ...   ...   ...    ...    ...    ...    ...    ...    ...
# 11690161   -1.80 -1.42 -1.20 -0.97  -0.75  -0.60  -0.45  -0.30  -0.15   0.00
# 11690162   -1.80 -1.43 -1.20 -0.98  -0.75  -0.60  -0.45  -0.30  -0.15  -0.08
# 11690205   -1.72 -1.35 -1.13 -0.90  -0.68  -0.53  -0.38  -0.15  -0.00   0.15
# 11690206   -1.80 -1.43 -1.13 -0.90  -0.75  -0.53  -0.38  -0.23  -0.08   0.07
# 11690207   -1.79 -1.50 -1.20 -0.97  -0.82  -0.67  -0.52  -0.37  -0.22  -0.07
#
# ...

# %%
 Trees_RH_Shot_5.columns
# Out:
# Index(['RH10', 'RH15', 'RH20', 'RH25', 'RH30', 'RH35', 'RH40', 'RH45', 'RH50',
#        'RH55', 'RH60', 'RH65', 'RH70', 'RH75', 'RH80', 'RH85', 'RH90', 'RH95',
#        'RH96', 'RH97', 'RH98', 'RH99', 'RH100', 'h_t_modmax', 'm_agb',
#        'h_t_modsum', 'tree_count', 'h_t_mod_sq_sum', 'h_t_modmean'],
#       dtype='object')

# %%
#TreesRH13_22.columns

# %%
#matplotlib.pyplot.scatter(Trees_RH.m_agb,Trees_RH.ZG,color='r') 
matplotlib.pyplot.scatter(Trees_RH_Shot_5.m_agb,Trees_RH_Shot_5.RH25,color='orange') 
matplotlib.pyplot.scatter(Trees_RH_Shot_5.m_agb,Trees_RH_Shot_5.RH50,color='y')
matplotlib.pyplot.scatter(Trees_RH_Shot_5.m_agb,Trees_RH_Shot_5.RH75,color='g')
matplotlib.pyplot.scatter(Trees_RH_Shot_5.m_agb,Trees_RH_Shot_5.RH100,color='b')
matplotlib.pyplot.show()

# %%
matplotlib.pyplot.scatter(Trees_RH_Shot_5.m_agb,Trees_RH_Shot_5.RH25,color='orange')

# %%
matplotlib.pyplot.scatter(Trees_RH_Shot_5.m_agb,Trees_RH_Shot_5.RH50,color='y')

# %%
matplotlib.pyplot.scatter(Trees_RH_Shot_5.m_agb,Trees_RH_Shot_5.RH75,color='g')

# %%
matplotlib.pyplot.scatter(Trees_RH_Shot_5.m_agb,Trees_RH_Shot_5.RH100,color='b')

# %%
import statsmodels.api as sm

# %%
from sklearn import datasets ## imports datasets from scikit-learn

# %%
#http://seaborn.pydata.org/tutorial/regression.html

# %%
#This is where the chart come from

# %%
#Trees_RH_Shot_5

# %%
#PLOT 'NASA21A' - 5m - RH25

# %% [markdown]
# #### RH25

# %%
X = Trees_RH_Shot_5['m_agb']
y = Trees_RH_Shot_5["RH25"]

# Note the difference in argument order
model = sm.OLS(y, X).fit()
predictions = model.predict(X) # make the predictions by the model

# Print out the statistics
model.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                                  OLS Regression Results
# ...
# Dep. Variable:                   RH25   R-squared (uncentered):                   0.491
# Model:                            OLS   Adj. R-squared (uncentered):              0.490
# Method:                 Least Squares   F-statistic:                              746.5
# Date:                Tue, 10 Nov 2020   Prob (F-statistic):                   1.22e-115
# Time:                        19:55:09   Log-Likelihood:                         -2468.6
# No. Observations:                 776   AIC:                                      4939.
# Df Residuals:                     775   BIC:                                      4944.
# Df Model:                           1
# Covariance Type:            nonrobust
# ...
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# ...

# %%
sns.regplot(x='m_agb', y="RH25", data=Trees_RH_Shot_5);

# %% [markdown]
# #### RH50

# %%
X = Trees_RH_Shot_5['m_agb']
y = Trees_RH_Shot_5["RH50"]

# Note the difference in argument order
model = sm.OLS(y, X).fit()
predictions = model.predict(X) # make the predictions by the model

# Print out the statistics
model.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                                  OLS Regression Results
# ...
# Dep. Variable:                   RH50   R-squared (uncentered):                   0.556
# Model:                            OLS   Adj. R-squared (uncentered):              0.555
# Method:                 Least Squares   F-statistic:                              969.2
# Date:                Tue, 10 Nov 2020   Prob (F-statistic):                   1.16e-138
# Time:                        19:55:10   Log-Likelihood:                         -2713.6
# No. Observations:                 776   AIC:                                      5429.
# Df Residuals:                     775   BIC:                                      5434.
# Df Model:                           1
# Covariance Type:            nonrobust
# ...
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# ...

# %%
sns.regplot(x='m_agb', y="RH50", data=Trees_RH_Shot_5);

# %% [markdown]
# #### RH75

# %%
X = Trees_RH_Shot_5['m_agb']
y = Trees_RH_Shot_5["RH75"]

# Note the difference in argument order
model = sm.OLS(y, X).fit()
predictions = model.predict(X) # make the predictions by the model

# Print out the statistics
model.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                                  OLS Regression Results
# ...
# Dep. Variable:                   RH75   R-squared (uncentered):                   0.537
# Model:                            OLS   Adj. R-squared (uncentered):              0.536
# Method:                 Least Squares   F-statistic:                              898.7
# Date:                Tue, 10 Nov 2020   Prob (F-statistic):                   1.05e-131
# Time:                        19:55:10   Log-Likelihood:                         -2936.7
# No. Observations:                 776   AIC:                                      5875.
# Df Residuals:                     775   BIC:                                      5880.
# Df Model:                           1
# Covariance Type:            nonrobust
# ...
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# ...

# %%
sns.regplot(x='m_agb', y="RH75", data=Trees_RH_Shot_5);

# %% [markdown]
# ##### RH100

# %%
X = Trees_RH_Shot_5['m_agb']
y = Trees_RH_Shot_5["RH100"]

# Note the difference in argument order
model = sm.OLS(y, X).fit()
predictions = model.predict(X) # make the predictions by the model

# Print out the statistics
model.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                                  OLS Regression Results
# ...
# Dep. Variable:                  RH100   R-squared (uncentered):                   0.437
# Model:                            OLS   Adj. R-squared (uncentered):              0.436
# Method:                 Least Squares   F-statistic:                              601.9
# Date:                Tue, 10 Nov 2020   Prob (F-statistic):                    8.16e-99
# Time:                        19:55:11   Log-Likelihood:                         -3359.0
# No. Observations:                 776   AIC:                                      6720.
# Df Residuals:                     775   BIC:                                      6725.
# Df Model:                           1
# Covariance Type:            nonrobust
# ...
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# ...

# %%
sns.regplot(x='m_agb', y="RH100", data=Trees_RH_Shot_5);

# %%
## Quadratic canopy profile

# %%
Trees_RH_Shot_5['Canopy_Profile'] = (Trees_RH_Shot_5['h_t_mod_sq_sum'] / Trees_RH_Shot_5['tree_count'] )**.5

# %%
Trees_RH_Shot_5.head()
# Out:
#             RH10  RH15  RH20  RH25   RH30   RH35   RH40   RH45   RH50   RH55  \
# SHOTNUMBER
# 9361768     5.46  7.34  8.53  9.43  10.11  10.70  11.30  11.98  12.73  13.47
# 9361769     3.60  5.39  6.37  7.04   7.57   8.09   8.61   9.06   9.51   9.96
# 9361773    -1.28 -0.83 -0.45 -0.08   0.30   0.67   1.12   1.79   2.77   3.67
# 9361774    -1.42 -1.05 -0.75 -0.52  -0.30  -0.08   0.15   0.37   0.60   0.90
# 9361775    -1.09 -0.87 -0.64 -0.49  -0.27  -0.12   0.11   0.26   0.48   0.63
#
#             ...   RH98   RH99  RH100  h_t_modmax    m_agb  h_t_modsum  \
# SHOTNUMBER  ...
# 9361768     ...  20.51  21.03  22.08       16.43  1905.25      441.85
# 9361769     ...  15.43  16.62  19.24       16.32  1664.24      390.40
# 9361773     ...  17.59  19.02  20.96       19.06  2181.50      168.20
# 9361774     ...  11.53  12.88  15.20       19.06  1864.96      126.64
# 9361775     ...  20.25  23.02  25.35       17.38   455.09       44.19
#
# ...

# %%
Trees_RH_Shot_5.to_csv(r'D:\Gabon_Lidar\DATA\pandas_csv\Trees_RH_Shot_5_CP.csv')
Trees_RH_Shot_125 =pd.read_csv(r'D:\Gabon_Lidar\DATA\pandas_csv\Trees_RH_Shot_5_CP.csv')

# %%
## Quadratic canopy profile

# %%
SQRT((sum(h_t**2)/count())
# Out:
#   File "<ipython-input-108-5586866b43d5>", line 1
#     SQRT((sum(h_t**2)/count())
#                               ^
# SyntaxError: unexpected EOF while parsing

# %%
matplotlib.pyplot.scatter(Trees_RH_Shot_5.m_agb,Trees_RH_Shot_5.Canopy_Profile,color='b')

# %%
sns.regplot(x='m_agb', y="Canopy_Profile", data=Trees_RH_Shot_5);

# %% [markdown]
# MLR

# %%
#MLR- ALL RHvaleus

# %%
#https://towardsdatascience.com/simple-and-multiple-linear-regression-in-python-c928425168f9

# %%
#https://www.youtube.com/watch?v=J_LnPL3Qg70

# %%
 Trees_RH_Shot_5.columns
# Out:
# Index(['RH10', 'RH15', 'RH20', 'RH25', 'RH30', 'RH35', 'RH40', 'RH45', 'RH50',
#        'RH55', 'RH60', 'RH65', 'RH70', 'RH75', 'RH80', 'RH85', 'RH90', 'RH95',
#        'RH96', 'RH97', 'RH98', 'RH99', 'RH100', 'h_t_modmax', 'm_agb',
#        'h_t_modsum', 'tree_count', 'h_t_mod_sq_sum', 'h_t_modmean',
#        'Canopy_Profile'],
#       dtype='object')

# %%
import pandas as pd 
import numpy as np 
from sklearn import linear_model

# %%
df =Trees_RH_Shot_5

# %%
#caluclating m_agb

# %%
reg = linear_model.LinearRegression()

# %%
reg.fit(df[['RH10', 'RH15', 'RH20', 'RH25', 'RH30', 'RH35', 'RH40', 'RH45', 'RH50',
       'RH55', 'RH60', 'RH65', 'RH70', 'RH75', 'RH80', 'RH85', 'RH90', 'RH95',
       'RH96', 'RH97', 'RH98', 'RH99', 'RH100']],df.m_agb)
# Out:
# LinearRegression()

# %%
reg.coef_
# Out:
# array([  979.84035637, -1197.30523585,   -37.38995823,   718.46263884,
#         1728.67103685, -8518.56793352, 11420.99783715, -5387.18574846,
#         1475.14702876,  -796.32022971,   242.77593618,  -322.50404927,
#           87.51033679,   354.85588333,    45.68267745,    58.4506709 ,
#         -274.08904777,   138.04743212,   269.33693317,  -197.48858673,
#         -341.79852997,   199.27267821,    92.26007501])

# %%
reg.intercept_
# Out:
# -107.22166563503743

# %%
#caluclating Canopy_Profile

# %%
reg = linear_model.LinearRegression()

# %%
reg.fit(df[['RH10', 'RH15', 'RH20', 'RH25', 'RH30', 'RH35', 'RH40', 'RH45', 'RH50',
       'RH55', 'RH60', 'RH65', 'RH70', 'RH75', 'RH80', 'RH85', 'RH90', 'RH95',
       'RH96', 'RH97', 'RH98', 'RH99', 'RH100']],df.Canopy_Profile)
# Out:
# LinearRegression()

# %%
reg.coef_
# Out:
# array([-0.28649331,  0.36036427, -0.29941738,  0.25467287, -0.16631042,
#         0.32489573, -0.64557291,  0.80355605, -0.43762388,  0.16940623,
#        -0.26569337,  0.40684306, -0.20866579,  0.05172284, -0.0678589 ,
#        -0.1080454 ,  0.12317673, -0.02244358,  0.21690894, -0.03932505,
#        -0.20259255, -0.04920898,  0.18808066])

# %%
reg.intercept_
# Out:
# 10.26759225730142

# %%
#MLR- RH25, RH50, RH75 RH100

# %%
df =Trees_RH_Shot_5

# %%
reg = linear_model.LinearRegression()

# %%
reg.fit(df[[ 'RH25', 'RH50',
       'RH75', 'RH100']],df.m_agb)
# Out:
# LinearRegression()

# %%
reg.coef_
# Out:
# array([-90.13593041, 597.60574471,  64.06443341,  42.66559431])

# %%
reg.intercept_
# Out:
# -836.8099975090145

# %%
reg.fit(df[[ 'RH25', 'RH50',
       'RH75', 'RH100']],df.Canopy_Profile)
# Out:
# LinearRegression()

# %%
reg.coef_
# Out:
# array([-0.00034696,  0.07682104, -0.0210669 ,  0.09023377])

# %%
reg.intercept_
# Out:
# 10.63943097185356

# %%
from sklearn import datasets ## imports datasets from scikit-learn
data = Trees_RH_Shot_5 ## loads Boston dataset from datasets library

# %%
Trees_RH_Shot_5.columns
# Out:
# Index(['RH10', 'RH15', 'RH20', 'RH25', 'RH30', 'RH35', 'RH40', 'RH45', 'RH50',
#        'RH55', 'RH60', 'RH65', 'RH70', 'RH75', 'RH80', 'RH85', 'RH90', 'RH95',
#        'RH96', 'RH97', 'RH98', 'RH99', 'RH100', 'h_t_modmax', 'm_agb',
#        'h_t_modsum', 'tree_count', 'h_t_mod_sq_sum', 'h_t_modmean',
#        'Canopy_Profile'],
#       dtype='object')

# %% [markdown]
# **SLICER data collection and processing**

# %% [markdown]
# SLICER data were collected from airborne platforms at
# the temperate coniferous, boreal coniferous and temperate
# deciduous sites in September 1995, July 1996 and September
# 1995, respectively. Lidar waveforms were collected over contiguous 10-m footprints for five lidar waveforms across the
# sampling swath. To estimate canopy height profiles (CHPs,
# the vertical distribution of foliage and woody surfaces) from
# the raw SLICER waveforms, Harding et al. (2001) adapted the
# transformation method developed by MacArthur & Horn
# (1969). The resulting CHPs serve as a common measurement
# of forest canopy structure at the three sites. One key factor in
# the CHP algorithm is a coefficient defined as the ratio of the
# average reflectance (at nadir) of the ground and canopy at the
# laser wavelength (1064 nanometres). For the temperate
# deciduous and temperate coniferous sites, the ratio of ground
# and canopy reflectance is assumed to be 2.0. Use of this
# assumption has been supported by fieldwork comparing lidar
# estimates and field measurements of canopy cover at these sites
# (Lefsky, 1997; Means et al., 1999). At the boreal coniferous
# site, the existence of a high ground-level cover of herbaceous
# moss and fern species and a small dataset of coincident lidar
# and field measurements of cover imply that this ratio should
# be close to 1.0, the value used in calculations for this site.
#     Canopy structure indices used in this study were calculated
# for each plot from CHPs following the methods of Lefsky
# et al. (1999a). A variety of indices were selected from our
# previous work in the temperate sites and preliminary work
# with the boreal coniferous dataset. The indices are canopy
# cover, mean canopy height (MCH, the average height of the
# waveforms associated with a plot), maximum height (the
# maximum height of the same set of waveforms), MCH squared,
# and the mean canopy profile height, defined as:
# Mean canopy profile height =
# where: CHP(i) is the normalized canopy height profile at
# height i, and h is the maximum height of the canopy.
# The quadratic canopy profile height is defined as:
# Quadratic canopy profile height =
# In addition to considering the height and canopy cover
# variables separately, the products of canopy cover and each of
# the height indices were also considered, as suggested by our
# initial experience with the boreal site. At the eastern deciduous
# site, 64 plots with lidar-estimated CHPs were supplemented
# with 48 plots with field-measured CHPs, to incorporate a
# greater range of stand conditions. Treating these two datasets
# as equivalent for the purposes of estimating above-ground
# biomass is supported by the findings of Lefsky et al. (1999a).
# Measurements of mean canopy height are not available
# for the field measured CHPs; a regression between quadratic
# mean canopy height and mean canopy surface height was
# developed using those plots with lidar measurements, and
# then applied to predict mean canopy height. Scatterplots of
# variable combinations were examined to ensure linearity.

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
Trees_RH_Shot_5.columns
# Out:
# Index(['RH10', 'RH15', 'RH20', 'RH25', 'RH30', 'RH35', 'RH40', 'RH45', 'RH50',
#        'RH55', 'RH60', 'RH65', 'RH70', 'RH75', 'RH80', 'RH85', 'RH90', 'RH95',
#        'RH96', 'RH97', 'RH98', 'RH99', 'RH100', 'h_t_modmax', 'm_agb',
#        'h_t_mod', 'h_t_sq_sum', 'h_t_modmean'],
#       dtype='object')

# %%
Trees_RH_Shot_5.h_t_modmean
# Out:
# SHOTNUMBER
# 9361768    11.941892
# 9361769    11.830303
# 9361773    15.290909
# 9361774    15.830000
# 9361775    14.730000
#              ...
# 9362444    13.849444
# 9362445    16.163333
# 9362446    17.427917
# 9362447    14.116154
# 9362448    13.459444
# Name: h_t_modmean, Length: 63, dtype: float64

# %%
(h_t_modmean**2)/

# %%
Trees_RH_Shot_5.h_t_modmax
# Out:
# SHOTNUMBER
# 9361768    16.43
# 9361769    16.32
# 9361773    19.06
# 9361774    19.06
# 9361775    17.38
#            ...
# 9362444    29.94
# 9362445    36.80
# 9362446    36.80
# 9362447    23.74
# 9362448    23.74
# Name: h_t_modmax, Length: 63, dtype: float64

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
import seaborn as sns

# %%
sns.regplot(x='m_agb', y="RH100", data=Trees_RH_Shot_5);

# %%
#

# %%
sns.regplot(x='Trees_RH_Shot_5['m_agb']', y='Trees_RH_Shot_5["RH100"]', data=motif)
# Out:
#   File "<ipython-input-92-bb9eba48c3b2>", line 1
#     sns.regplot(x='Trees_RH_Shot_5['m_agb']', y='Trees_RH_Shot_5["RH100"]', data=motif)
#                                     ^
# SyntaxError: invalid syntax

# %%
Trees_RH_Shot_5.plot()
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# ~\anaconda3\envs\G_H_GEDI\lib\site-packages\pandas\core\indexes\base.py in get_loc(self, key, method, tolerance)
#    2888             try:
# -> 2889                 return self._engine.get_loc(casted_key)
#    2890             except KeyError as err:
#
# pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'Trees_RH_Shot_5["m_agb"]'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# <ipython-input-89-500743b00f42> in <module>
# ...

# %%
## Without a constant

import statsmodels.api as sm

X = df["RM"]
y = target["RH25"]

# Note the difference in argument order
model = sm.OLS(y, X).fit()
predictions = model.predict(X) # make the predictions by the model

# Print out the statistics
model.summary()
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# ~\anaconda3\envs\G_H_GEDI\lib\site-packages\pandas\core\indexes\base.py in get_loc(self, key, method, tolerance)
#    2888             try:
# -> 2889                 return self._engine.get_loc(casted_key)
#    2890             except KeyError as err:
#
# pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'RH25'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# <ipython-input-8-767bb31f2df0> in <module>
#       4
# ...
