# %% [markdown]
# #geopandas

# %% [markdown]
# #https://lvis.gsfc.nasa.gov/workshop/LVIS_QGIS_Tutorial_Gabon.pdf

# %%
import matplotlib.pyplot 
import numpy as np
import pylab
import pandas as pd
import h5py
import geopandas as gpd
from shapely.geometry import *
from geopandas.geoseries import *
from geopandas import GeoDataFrame
from shapely.geometry import Point
import fiona
import seaborn as sns

# %% [markdown]
# Bring all the data data in

# %%
# Geopandas

# %%
#Trees

# %%
# This convert a csv to a shpage file

# %%
df = pd.read_csv('D:\Gabon_Lidar\DATA\pandas_csv\Mondah_Field_Data_Trees.csv')

geometry = [Point(xy) for xy in zip(df.x, df.y)]
crs = {'init': 'epsg:4326'} #http://www.spatialreference.org/ref/epsg/2263/
geo_df = GeoDataFrame(df, crs=crs, geometry=geometry)

geo_df.to_file(driver='ESRI Shapefile', filename='D:\Gabon_Lidar\DATA\shp\Mondah_Field_Data_Trees.shp')
# Out:
# C:\Users\17183\anaconda3\envs\G_H_GEDI\lib\site-packages\pyproj\crs\crs.py:53: FutureWarning: '+init=<authority>:<code>' syntax is deprecated. '<authority>:<code>' is the preferred initialization method. When making the change, be mindful of axis order changes: https://pyproj4.github.io/pyproj/stable/gotchas.html#axis-order-changes-in-proj-6
#   return _prepare_from_string(" ".join(pjargs))

# %%
#Trees

# %%
Trees = gpd.read_file(r'D:\Gabon_Lidar\DATA\shp\Mondah_Field_Data_Trees_in_study_site_lat_lon_a.shp')

# %%
Trees = gpd.read_file(r'D:\Gabon_Lidar\DATA\shp\Trees_clean_111020.shp')

# %%
Trees.plot()
# Out:
# <AxesSubplot:>

# %%
Trees = Trees.to_crs(epsg=4326)

# %%
Trees
# Out:
#       Join_Count    plot  subplot   tree_date           family  \
# 0              1  NASA01        1  2016-02-03    Euphorbiaceae
# 1              1  NASA01        1  2016-02-03    Euphorbiaceae
# 2              1  NASA01        1  2016-02-03    Euphorbiaceae
# 3              1  NASA01        1  2016-02-03    Euphorbiaceae
# 4              1  NASA01        1  2016-02-03    Euphorbiaceae
# ...          ...     ...      ...         ...              ...
# 6627           1  NASA23       14  2016-02-21               NA
# 6628           1  NASA23       14  2016-02-21               NA
# 6629           1  NASA23       14  2016-02-21    Myristicaceae
# 6630           1  NASA23       14  2016-02-21  Melastomataceae
# 6631           1  NASA23       14  2016-02-21               NA
#
#                     species       wsg  tree  stem   epsg  ...    a_stem  \
# 0             Macaranga sp.  0.381789  6501     1  32632  ...  0.011120
# 1             Macaranga sp.  0.381789  6502     1  32632  ...  0.008171
# 2             Macaranga sp.  0.381789  6503     1  32632  ...  0.009331
# 3             Macaranga sp.  0.381789  6504     1  32632  ...  0.011880
# 4             Macaranga sp.  0.381789  6505     1  32632  ...  0.009331
# ...                     ...       ...   ...   ...    ...  ...       ...
# 6627                     NA  0.534143  3903     1  32632  ...  0.243700
# 6628                     NA  0.534143  3904     1  32632  ...  0.260600
# 6629  Pycnanthus angolensis  0.408900  3905     1  32632  ...  0.022170
# 6630     Dichaetanthera sp.  0.609414  3906     1  32632  ...  0.010030
# 6631                     NA  0.534143  3907     1  32632  ...  0.086570
#
#          h_t  h_t_mod  d_stem  d_stem_val  d_ht    m_agb   POINT_X   POINT_Y  \
# 0    -9999.0    12.18   0.119           1  1.65    37.92  9.322006  0.554795
# 1    -9999.0    11.28   0.102           1  1.30    26.05  9.321989  0.554836
# 2    -9999.0    11.66   0.109           1  1.30    30.62  9.322007  0.554844
# 3    -9999.0    12.38   0.123           1  1.30    41.10  9.322008  0.554853
# 4    -9999.0    11.66   0.109           1  1.30    30.62  9.321998  0.554827
# ...      ...      ...     ...         ...   ...      ...       ...       ...
# 6627 -9999.0    26.15   0.557           1  1.60  2257.42  9.316524  0.545561
# 6628 -9999.0    26.59   0.576           1  1.30  2449.56  9.316515  0.545568
# 6629 -9999.0    14.45   0.168           1  1.30    93.90  9.316506  0.545571
# 6630 -9999.0    11.87   0.113           1  1.60    52.77  9.316561  0.545582
# 6631 -9999.0    20.24   0.332           1  1.30   640.25  9.316449  0.545587
#
#                      geometry
# 0     POINT (9.32201 0.55479)
# 1     POINT (9.32199 0.55484)
# 2     POINT (9.32201 0.55484)
# 3     POINT (9.32201 0.55485)
# 4     POINT (9.32200 0.55483)
# ...                       ...
# 6627  POINT (9.31652 0.54556)
# 6628  POINT (9.31652 0.54557)
# 6629  POINT (9.31651 0.54557)
# 6630  POINT (9.31656 0.54558)
# 6631  POINT (9.31645 0.54559)
#
# [6632 rows x 24 columns]

# %%
Trees.columns
# Out:
# Index(['Join_Count', 'plot', 'subplot', 'tree_date', 'family', 'species',
#        'wsg', 'tree', 'stem', 'epsg', 'x', 'y', 'status', 'allom_key',
#        'a_stem', 'h_t', 'h_t_mod', 'd_stem', 'd_stem_val', 'd_ht', 'm_agb',
#        'POINT_X', 'POINT_Y', 'geometry'],
#       dtype='object')

# %%
Trees.head(3)
# Out:
#    Join_Count    plot  subplot   tree_date         family        species  \
# 0           1  NASA01        1  2016-02-03  Euphorbiaceae  Macaranga sp.
# 1           1  NASA01        1  2016-02-03  Euphorbiaceae  Macaranga sp.
# 2           1  NASA01        1  2016-02-03  Euphorbiaceae  Macaranga sp.
#
#         wsg  tree  stem   epsg  ...    a_stem     h_t  h_t_mod  d_stem  \
# 0  0.381789  6501     1  32632  ...  0.011120 -9999.0    12.18   0.119
# 1  0.381789  6502     1  32632  ...  0.008171 -9999.0    11.28   0.102
# 2  0.381789  6503     1  32632  ...  0.009331 -9999.0    11.66   0.109
#
#    d_stem_val  d_ht  m_agb   POINT_X   POINT_Y                 geometry
# 0           1  1.65  37.92  9.322006  0.554795  POINT (9.32201 0.55479)
# 1           1  1.30  26.05  9.321989  0.554836  POINT (9.32199 0.55484)
# 2           1  1.30  30.62  9.322007  0.554844  POINT (9.32201 0.55484)
#
# [3 rows x 24 columns]

# %% [markdown]
# Selecting Tree with a measured height.

# %%
# List of plots  01,02,03,05,09,10,11,13,14,19,21,21A,22,23
# I think plot19 has problem with it's sample

# %%
#Trees = Trees[(Trees['plot'] == 'NASA14')]

# %%
#NOTE: 0nly 121 trees have h_t measurements

# %%
#Trees = Trees[(Trees['h_t'] > 0)]

# %%
Trees = Trees[(Trees['h_t'] > 0)]

# %%
Trees
# Out:
#       Join_Count     plot  subplot   tree_date          family  \
# 31             1   NASA01        4  2016-02-03      Annonaceae
# 35             1   NASA01        4  2016-02-03    Gentianaceae
# 80             1   NASA01        7  2016-02-03   Myristicaceae
# 81             1   NASA01        7  2016-02-03  Phyllanthaceae
# 86             1   NASA01        7  2016-02-03   Myristicaceae
# ...          ...      ...      ...         ...             ...
# 2266           1   NASA11       12  2016-02-10      Annonaceae
# 2280           1   NASA11       12  2016-02-10      Annonaceae
# 2968           1   NASA13       12  2016-02-04    Gentianaceae
# 4893           1  NASA21A        7  2016-02-11        Rutaceae
# 5159           1  NASA21A       12  2016-02-11       Rubiaceae
#
#                    species       wsg  tree  stem   epsg  ...    a_stem    h_t  \
# 31       Cleistopholis sp.  0.322350  6515     1  32632  ...  0.009852  13.17
# 35        Anthocleista sp.  0.537778  6519     1  32632  ...  0.016510  11.87
# 80         Coelocaryon sp.  0.493532  6526     1  32632  ...  0.047920  23.30
# 81      Protomegabaria sp.  0.602000  6527     1  32632  ...  0.019110  13.73
# 86         Coelocaryon sp.  0.493532  6532     1  32632  ...  0.017440  12.77
# ...                    ...       ...   ...   ...    ...  ...       ...    ...
# 2266     Cleistopholis sp.  0.322350  5634     1  32632  ...  0.092940  14.63
# 2280     Cleistopholis sp.  0.322350  5648     1  32632  ...  0.072580  16.87
# 2968      Anthocleista sp.  0.537778  5319     1  32632  ...  0.081940  17.20
# 4893  Zanthoxylum gilletii  0.686091  7054     1  32632  ...  0.020110  13.30
# 5159            Hallea sp.  0.473429  7249     1  32632  ...  0.051870  20.90
#
#       h_t_mod  d_stem  d_stem_val  d_ht   m_agb   POINT_X   POINT_Y  \
# 31      11.82   0.112           1   1.3   30.82  9.322191  0.555535
# 35      13.43   0.145           1   1.3   75.97  9.322192  0.555444
# 80      17.48   0.247           1   1.6  381.75  9.322392  0.555147
# 81      13.93   0.156           1   1.6  112.81  9.322343  0.555158
# 86      13.61   0.149           1   1.6   79.12  9.322251  0.555107
# ...       ...     ...         ...   ...     ...       ...       ...
# 2266    20.60   0.344           1   1.3  305.41  9.319974  0.538962
# 2280    19.38   0.304           1   1.3  275.61  9.320052  0.539131
# 2968    19.97   0.323           1   2.3  521.10  9.357443  0.577159
# 4893    14.10   0.160           1   1.6  130.51  9.381854  0.576541
# 5159    17.83   0.257           1   1.4  356.22  9.381917  0.577018
#
#                      geometry
# 31    POINT (9.32219 0.55553)
# 35    POINT (9.32219 0.55544)
# 80    POINT (9.32239 0.55515)
# 81    POINT (9.32234 0.55516)
# 86    POINT (9.32225 0.55511)
# ...                       ...
# 2266  POINT (9.31997 0.53896)
# 2280  POINT (9.32005 0.53913)
# 2968  POINT (9.35744 0.57716)
# 4893  POINT (9.38185 0.57654)
# 5159  POINT (9.38192 0.57702)
#
# [121 rows x 24 columns]

# %%
Trees['tree_count'] = 1
# Out:
# C:\Users\17183\anaconda3\envs\G_H_GEDI\lib\site-packages\geopandas\geodataframe.py:853: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   super(GeoDataFrame, self).__setitem__(key, value)

# %%
Trees
# Out:
#       Join_Count     plot  subplot   tree_date          family  \
# 31             1   NASA01        4  2016-02-03      Annonaceae
# 35             1   NASA01        4  2016-02-03    Gentianaceae
# 80             1   NASA01        7  2016-02-03   Myristicaceae
# 81             1   NASA01        7  2016-02-03  Phyllanthaceae
# 86             1   NASA01        7  2016-02-03   Myristicaceae
# ...          ...      ...      ...         ...             ...
# 2266           1   NASA11       12  2016-02-10      Annonaceae
# 2280           1   NASA11       12  2016-02-10      Annonaceae
# 2968           1   NASA13       12  2016-02-04    Gentianaceae
# 4893           1  NASA21A        7  2016-02-11        Rutaceae
# 5159           1  NASA21A       12  2016-02-11       Rubiaceae
#
#                    species       wsg  tree  stem   epsg  ...    h_t  h_t_mod  \
# 31       Cleistopholis sp.  0.322350  6515     1  32632  ...  13.17    11.82
# 35        Anthocleista sp.  0.537778  6519     1  32632  ...  11.87    13.43
# 80         Coelocaryon sp.  0.493532  6526     1  32632  ...  23.30    17.48
# 81      Protomegabaria sp.  0.602000  6527     1  32632  ...  13.73    13.93
# 86         Coelocaryon sp.  0.493532  6532     1  32632  ...  12.77    13.61
# ...                    ...       ...   ...   ...    ...  ...    ...      ...
# 2266     Cleistopholis sp.  0.322350  5634     1  32632  ...  14.63    20.60
# 2280     Cleistopholis sp.  0.322350  5648     1  32632  ...  16.87    19.38
# 2968      Anthocleista sp.  0.537778  5319     1  32632  ...  17.20    19.97
# 4893  Zanthoxylum gilletii  0.686091  7054     1  32632  ...  13.30    14.10
# 5159            Hallea sp.  0.473429  7249     1  32632  ...  20.90    17.83
#
#       d_stem  d_stem_val  d_ht   m_agb   POINT_X   POINT_Y  \
# 31     0.112           1   1.3   30.82  9.322191  0.555535
# 35     0.145           1   1.3   75.97  9.322192  0.555444
# 80     0.247           1   1.6  381.75  9.322392  0.555147
# 81     0.156           1   1.6  112.81  9.322343  0.555158
# 86     0.149           1   1.6   79.12  9.322251  0.555107
# ...      ...         ...   ...     ...       ...       ...
# 2266   0.344           1   1.3  305.41  9.319974  0.538962
# 2280   0.304           1   1.3  275.61  9.320052  0.539131
# 2968   0.323           1   2.3  521.10  9.357443  0.577159
# 4893   0.160           1   1.6  130.51  9.381854  0.576541
# 5159   0.257           1   1.4  356.22  9.381917  0.577018
#
#                      geometry  tree_count
# 31    POINT (9.32219 0.55553)           1
# 35    POINT (9.32219 0.55544)           1
# 80    POINT (9.32239 0.55515)           1
# 81    POINT (9.32234 0.55516)           1
# 86    POINT (9.32225 0.55511)           1
# ...                       ...         ...
# 2266  POINT (9.31997 0.53896)           1
# 2280  POINT (9.32005 0.53913)           1
# 2968  POINT (9.35744 0.57716)           1
# 4893  POINT (9.38185 0.57654)           1
# 5159  POINT (9.38192 0.57702)           1
#
# [121 rows x 25 columns]

# %%
Trees.plot()
# Out:
# <AxesSubplot:>

# %%
#LVIS9421011 = LVISpoints[(LVISpoints.SHOTNUMBER == 9421011)]

# %%
#LVIS

# %%
#LVIS = gpd.read_file(r'D:\Gabon_Lidar\DATA\shp\LVIS2_Gabon2016_0308_R1808_studyarea.shp')

# %%
#These were buffered in arc pro

# %%
#LVIS = gpd.read_file(r'D:\Gabon_Lidar\DATA\shp\LVIS2_Gabon2016_0308_R1808_studyarea.shp')

# %%
#LVIS_5m = gpd.read_file(r'D:\Gabon_Lidar\DATA\shp\LVIS2_Gabon2016_5m.shp')

# %%
#LVIS_10m = gpd.read_file(r'D:\Gabon_Lidar\DATA\shp\LVIS2_Gabon2016_10m.shp')

# %%
LVIS_5m = gpd.read_file(r'D:\Gabon_Lidar\DATA\shp\LVIS2_Gabon2016_125m.shp')

# %%
LVIS_5m
# Out:
#            LFID  SHOTNUMBER       TIME      GLON      GLAT     ZG  HLON  HLAT  \
# 0    1657455174    11689486  48006.889  9.422888  0.617327  17.89  -999  -999
# 1    1657455174    11689489  48006.892  9.422886  0.617044  17.57  -999  -999
# 2    1657455174    11689490  48006.893  9.422886  0.616949  17.68  -999  -999
# 3    1657455174    11689493  48006.896  9.422884  0.616666  17.46  -999  -999
# 4    1657455174    11689494  48006.897  9.422884  0.616572  17.47  -999  -999
# ..          ...         ...        ...       ...       ...    ...   ...   ...
# 823  1657455148     9911421  46228.812  9.330292  0.546591  25.30  -999  -999
# 824  1657455148     9911422  46228.813  9.330293  0.546496  24.39  -999  -999
# 825  1657455148     9911424  46228.815  9.330295  0.546308  26.94  -999  -999
# 826  1657455148     9911425  46228.816  9.330296  0.546213  24.59  -999  -999
# 827  1657455148     9911426  46228.817  9.330297  0.546119  25.45  -999  -999
#
#       ZH      TLON  ...  CHANNEL_L1  CHANNEL_ZG  CHANNEL_RH   POINT_X  \
# 0   -999  9.422889  ...           1           1           1  9.422888
# 1   -999  9.422886  ...           1           1           1  9.422886
# 2   -999  9.422886  ...           1           1           1  9.422886
# 3   -999  9.422884  ...           1           1           1  9.422884
# 4   -999  9.422884  ...           1           1           1  9.422884
# ..   ...       ...  ...         ...         ...         ...       ...
# 823 -999  9.330292  ...           2           2           1  9.330292
# 824 -999  9.330293  ...           1           1           1  9.330293
# 825 -999  9.330295  ...           1           1           1  9.330295
# 826 -999  9.330296  ...           1           1           1  9.330296
# 827 -999  9.330297  ...           1           1           1  9.330297
#
#       POINT_Y  BUFF_DIST  ORIG_FID  Shape_Leng    Shape_Area  \
# 0    0.617327       12.5         0    0.000707  3.967907e-08
# 1    0.617044       12.5         1    0.000707  3.967906e-08
# 2    0.616949       12.5         2    0.000707  3.967915e-08
# 3    0.616666       12.5         3    0.000707  3.967908e-08
# 4    0.616572       12.5         4    0.000707  3.967908e-08
# ..        ...        ...       ...         ...           ...
# 823  0.546591       12.5       823    0.000707  3.967867e-08
# 824  0.546496       12.5       824    0.000707  3.967872e-08
# 825  0.546308       12.5       825    0.000707  3.967860e-08
# 826  0.546213       12.5       826    0.000707  3.967864e-08
# 827  0.546119       12.5       827    0.000707  3.967874e-08
#
#                                               geometry
# 0    POLYGON ((9.42289 0.61744, 9.42291 0.61744, 9....
# 1    POLYGON ((9.42289 0.61716, 9.42291 0.61716, 9....
# 2    POLYGON ((9.42289 0.61706, 9.42291 0.61706, 9....
# 3    POLYGON ((9.42288 0.61678, 9.42290 0.61678, 9....
# 4    POLYGON ((9.42288 0.61669, 9.42290 0.61668, 9....
# ..                                                 ...
# 823  POLYGON ((9.33029 0.54670, 9.33031 0.54670, 9....
# 824  POLYGON ((9.33029 0.54661, 9.33031 0.54661, 9....
# 825  POLYGON ((9.33029 0.54642, 9.33031 0.54642, 9....
# 826  POLYGON ((9.33030 0.54633, 9.33032 0.54632, 9....
# 827  POLYGON ((9.33030 0.54623, 9.33032 0.54623, 9....
#
# [828 rows x 49 columns]

# %%
#Changing CRS 
LVIS_5m= LVIS_5m.to_crs(epsg=4326)

# %%
#LVIS = LVIS[(LVIS.SHOTNUMBER == 11689486)]
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-454-9c49479fb4ba> in <module>
# ----> 1 LVIS = LVIS[(LVIS.SHOTNUMBER == 11689486)]
#
# NameError: name 'LVIS' is not defined

# %%
LVIS_5m.head()

# %%
LVIS_5m.plot()
# Out:
# <AxesSubplot:>

# %%
Trees.columns
# Out:
# Index(['Join_Count', 'plot', 'subplot', 'tree_date', 'family', 'species',
#        'wsg', 'tree', 'stem', 'epsg', 'x', 'y', 'status', 'allom_key',
#        'a_stem', 'h_t', 'h_t_mod', 'd_stem', 'd_stem_val', 'd_ht', 'm_agb',
#        'POINT_X', 'POINT_Y', 'geometry', 'tree_count'],
#       dtype='object')

# %%
#Trees= Trees[(Trees.tree == 6808)]

# %%
Trees
# Out:
#       Join_Count     plot  subplot   tree_date          family  \
# 31             1   NASA01        4  2016-02-03      Annonaceae
# 35             1   NASA01        4  2016-02-03    Gentianaceae
# 80             1   NASA01        7  2016-02-03   Myristicaceae
# 81             1   NASA01        7  2016-02-03  Phyllanthaceae
# 86             1   NASA01        7  2016-02-03   Myristicaceae
# ...          ...      ...      ...         ...             ...
# 2266           1   NASA11       12  2016-02-10      Annonaceae
# 2280           1   NASA11       12  2016-02-10      Annonaceae
# 2968           1   NASA13       12  2016-02-04    Gentianaceae
# 4893           1  NASA21A        7  2016-02-11        Rutaceae
# 5159           1  NASA21A       12  2016-02-11       Rubiaceae
#
#                    species       wsg  tree  stem   epsg  ...    h_t  h_t_mod  \
# 31       Cleistopholis sp.  0.322350  6515     1  32632  ...  13.17    11.82
# 35        Anthocleista sp.  0.537778  6519     1  32632  ...  11.87    13.43
# 80         Coelocaryon sp.  0.493532  6526     1  32632  ...  23.30    17.48
# 81      Protomegabaria sp.  0.602000  6527     1  32632  ...  13.73    13.93
# 86         Coelocaryon sp.  0.493532  6532     1  32632  ...  12.77    13.61
# ...                    ...       ...   ...   ...    ...  ...    ...      ...
# 2266     Cleistopholis sp.  0.322350  5634     1  32632  ...  14.63    20.60
# 2280     Cleistopholis sp.  0.322350  5648     1  32632  ...  16.87    19.38
# 2968      Anthocleista sp.  0.537778  5319     1  32632  ...  17.20    19.97
# 4893  Zanthoxylum gilletii  0.686091  7054     1  32632  ...  13.30    14.10
# 5159            Hallea sp.  0.473429  7249     1  32632  ...  20.90    17.83
#
#       d_stem  d_stem_val  d_ht   m_agb   POINT_X   POINT_Y  \
# 31     0.112           1   1.3   30.82  9.322191  0.555535
# 35     0.145           1   1.3   75.97  9.322192  0.555444
# 80     0.247           1   1.6  381.75  9.322392  0.555147
# 81     0.156           1   1.6  112.81  9.322343  0.555158
# 86     0.149           1   1.6   79.12  9.322251  0.555107
# ...      ...         ...   ...     ...       ...       ...
# 2266   0.344           1   1.3  305.41  9.319974  0.538962
# 2280   0.304           1   1.3  275.61  9.320052  0.539131
# 2968   0.323           1   2.3  521.10  9.357443  0.577159
# 4893   0.160           1   1.6  130.51  9.381854  0.576541
# 5159   0.257           1   1.4  356.22  9.381917  0.577018
#
#                      geometry  tree_count
# 31    POINT (9.32219 0.55553)           1
# 35    POINT (9.32219 0.55544)           1
# 80    POINT (9.32239 0.55515)           1
# 81    POINT (9.32234 0.55516)           1
# 86    POINT (9.32225 0.55511)           1
# ...                       ...         ...
# 2266  POINT (9.31997 0.53896)           1
# 2280  POINT (9.32005 0.53913)           1
# 2968  POINT (9.35744 0.57716)           1
# 4893  POINT (9.38185 0.57654)           1
# 5159  POINT (9.38192 0.57702)           1
#
# [121 rows x 25 columns]

# %%
#Trees= Trees[(Trees.SHOTNUMBER == 9899422)]

# %%
Trees_LVIS_5m = gpd.overlay(Trees,LVIS_5m, how = 'intersection')

# %%
Trees_LVIS_5m
# Out:
#      Join_Count     plot  subplot   tree_date        family  \
# 0             1   NASA02        1  2016-02-05    Annonaceae
# 1             1   NASA02        1  2016-02-05    Annonaceae
# 2             1   NASA02        1  2016-02-05    Annonaceae
# 3             1   NASA02        1  2016-02-05    Annonaceae
# 4             1   NASA02        1  2016-02-05  Vochysiaceae
# ..          ...      ...      ...         ...           ...
# 173           1  NASA21A        7  2016-02-11      Rutaceae
# 174           1  NASA21A        7  2016-02-11      Rutaceae
# 175           1  NASA21A       12  2016-02-11     Rubiaceae
# 176           1  NASA21A       12  2016-02-11     Rubiaceae
# 177           1  NASA21A       12  2016-02-11     Rubiaceae
#
#                   species       wsg  tree  stem   epsg  ...  CHANNEL_L1  \
# 0             Xylopia sp.  0.591038  6619     1  32632  ...           1
# 1             Xylopia sp.  0.591038  6619     1  32632  ...           1
# 2             Xylopia sp.  0.591038  6619     1  32632  ...           1
# 3             Xylopia sp.  0.591038  6619     1  32632  ...           1
# 4     Erismadelphus exsul  0.607100  6626     1  32632  ...           1
# ..                    ...       ...   ...   ...    ...  ...         ...
# 173  Zanthoxylum gilletii  0.686091  7054     1  32632  ...           1
# 174  Zanthoxylum gilletii  0.686091  7054     1  32632  ...           1
# 175            Hallea sp.  0.473429  7249     1  32632  ...           1
# 176            Hallea sp.  0.473429  7249     1  32632  ...           1
# 177            Hallea sp.  0.473429  7249     1  32632  ...           1
#
#      CHANNEL_ZG  CHANNEL_RH  POINT_X_2  POINT_Y_2  BUFF_DIST  ORIG_FID  \
# 0             1           1   9.318113   0.551334       12.5       578
# 1             1           1   9.318115   0.551240       12.5       579
# 2             1           1   9.318230   0.551239       12.5       582
# 3             1           1   9.318229   0.551334       12.5       583
# 4             1           1   9.318229   0.551334       12.5       583
# ..          ...         ...        ...        ...        ...       ...
# 173           1           1   9.381815   0.576620       12.5       290
# 174           1           1   9.381815   0.576526       12.5       291
# 175           1           1   9.381960   0.576966       12.5       281
# 176           1           1   9.381959   0.577061       12.5       282
# 177           1           1   9.381816   0.576996       12.5       286
#
#      Shape_Leng    Shape_Area                 geometry
# 0      0.000707  3.967866e-08  POINT (9.31817 0.55132)
# 1      0.000707  3.967857e-08  POINT (9.31817 0.55132)
# 2      0.000707  3.967862e-08  POINT (9.31817 0.55132)
# 3      0.000707  3.967866e-08  POINT (9.31817 0.55132)
# 4      0.000707  3.967866e-08  POINT (9.31832 0.55132)
# ..          ...           ...                      ...
# 173    0.000707  3.967891e-08  POINT (9.38185 0.57654)
# 174    0.000707  3.967891e-08  POINT (9.38185 0.57654)
# 175    0.000707  3.967881e-08  POINT (9.38192 0.57702)
# 176    0.000707  3.967873e-08  POINT (9.38192 0.57702)
# 177    0.000707  3.967890e-08  POINT (9.38192 0.57702)
#
# [178 rows x 73 columns]

# %%
#Trees_LVIS_5m = Trees_LVIS_5m[(Trees_LVIS_5m.SHOTNUMBER == 9899422)]

# %%
Trees_LVIS_5m
# Out:
#      Join_Count     plot  subplot   tree_date        family  \
# 0             1   NASA02        1  2016-02-05    Annonaceae
# 1             1   NASA02        1  2016-02-05    Annonaceae
# 2             1   NASA02        1  2016-02-05    Annonaceae
# 3             1   NASA02        1  2016-02-05    Annonaceae
# 4             1   NASA02        1  2016-02-05  Vochysiaceae
# ..          ...      ...      ...         ...           ...
# 173           1  NASA21A        7  2016-02-11      Rutaceae
# 174           1  NASA21A        7  2016-02-11      Rutaceae
# 175           1  NASA21A       12  2016-02-11     Rubiaceae
# 176           1  NASA21A       12  2016-02-11     Rubiaceae
# 177           1  NASA21A       12  2016-02-11     Rubiaceae
#
#                   species       wsg  tree  stem   epsg  ...  CHANNEL_L1  \
# 0             Xylopia sp.  0.591038  6619     1  32632  ...           1
# 1             Xylopia sp.  0.591038  6619     1  32632  ...           1
# 2             Xylopia sp.  0.591038  6619     1  32632  ...           1
# 3             Xylopia sp.  0.591038  6619     1  32632  ...           1
# 4     Erismadelphus exsul  0.607100  6626     1  32632  ...           1
# ..                    ...       ...   ...   ...    ...  ...         ...
# 173  Zanthoxylum gilletii  0.686091  7054     1  32632  ...           1
# 174  Zanthoxylum gilletii  0.686091  7054     1  32632  ...           1
# 175            Hallea sp.  0.473429  7249     1  32632  ...           1
# 176            Hallea sp.  0.473429  7249     1  32632  ...           1
# 177            Hallea sp.  0.473429  7249     1  32632  ...           1
#
#      CHANNEL_ZG  CHANNEL_RH  POINT_X_2  POINT_Y_2  BUFF_DIST  ORIG_FID  \
# 0             1           1   9.318113   0.551334       12.5       578
# 1             1           1   9.318115   0.551240       12.5       579
# 2             1           1   9.318230   0.551239       12.5       582
# 3             1           1   9.318229   0.551334       12.5       583
# 4             1           1   9.318229   0.551334       12.5       583
# ..          ...         ...        ...        ...        ...       ...
# 173           1           1   9.381815   0.576620       12.5       290
# 174           1           1   9.381815   0.576526       12.5       291
# 175           1           1   9.381960   0.576966       12.5       281
# 176           1           1   9.381959   0.577061       12.5       282
# 177           1           1   9.381816   0.576996       12.5       286
#
#      Shape_Leng    Shape_Area                 geometry
# 0      0.000707  3.967866e-08  POINT (9.31817 0.55132)
# 1      0.000707  3.967857e-08  POINT (9.31817 0.55132)
# 2      0.000707  3.967862e-08  POINT (9.31817 0.55132)
# 3      0.000707  3.967866e-08  POINT (9.31817 0.55132)
# 4      0.000707  3.967866e-08  POINT (9.31832 0.55132)
# ..          ...           ...                      ...
# 173    0.000707  3.967891e-08  POINT (9.38185 0.57654)
# 174    0.000707  3.967891e-08  POINT (9.38185 0.57654)
# 175    0.000707  3.967881e-08  POINT (9.38192 0.57702)
# 176    0.000707  3.967873e-08  POINT (9.38192 0.57702)
# 177    0.000707  3.967890e-08  POINT (9.38192 0.57702)
#
# [178 rows x 73 columns]

# %%
Trees_LVIS_5m['m_agb']
# Out:
# 0        45.83
# 1        45.83
# 2        45.83
# 3        45.83
# 4      1050.75
#         ...
# 173     130.51
# 174     130.51
# 175     356.22
# 176     356.22
# 177     356.22
# Name: m_agb, Length: 178, dtype: float64

# %%
Trees_LVIS_5m.columns
# Out:
# Index(['Join_Count', 'plot', 'subplot', 'tree_date', 'family', 'species',
#        'wsg', 'tree', 'stem', 'epsg', 'x', 'y', 'status', 'allom_key',
#        'a_stem', 'h_t', 'h_t_mod', 'd_stem', 'd_stem_val', 'd_ht', 'm_agb',
#        'POINT_X_1', 'POINT_Y_1', 'tree_count', 'LFID', 'SHOTNUMBER', 'TIME',
#        'GLON', 'GLAT', 'ZG', 'HLON', 'HLAT', 'ZH', 'TLON', 'TLAT', 'ZT',
#        'RH10', 'RH15', 'RH20', 'RH25', 'RH30', 'RH35', 'RH40', 'RH45', 'RH50',
#        'RH55', 'RH60', 'RH65', 'RH70', 'RH75', 'RH80', 'RH85', 'RH90', 'RH95',
#        'RH96', 'RH97', 'RH98', 'RH99', 'RH100', 'AZIMUTH', 'INCIDENTAN',
#        'RANGE', 'COMPLEXITY', 'CHANNEL_L1', 'CHANNEL_ZG', 'CHANNEL_RH',
#        'POINT_X_2', 'POINT_Y_2', 'BUFF_DIST', 'ORIG_FID', 'Shape_Leng',
#        'Shape_Area', 'geometry'],
#       dtype='object')

# %%
#SUM

# %%
sum = ['SHOTNUMBER', 'm_agb','h_t','tree_count']

# %%
Trees_RH_sum= Trees_LVIS_5m[sum]

# %%
Trees_RH_sum.head()
# Out:
#    SHOTNUMBER    m_agb   h_t  tree_count
# 0     9898827    45.83  13.0           1
# 1     9898828    45.83  13.0           1
# 2     9898971    45.83  13.0           1
# 3     9898972    45.83  13.0           1
# 4     9898972  1050.75  22.0           1

# %%
##Creat height ^2

# %%
Trees_RH_sum['h_t_sq_sum'] = Trees_RH_sum['h_t']**2
# Out:
# <ipython-input-471-f07bcba81618>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   Trees_RH_sum['h_t_sq_sum'] = Trees_RH_sum['h_t']**2

# %%
Trees_RH_sum
# Out:
#      SHOTNUMBER    m_agb   h_t  tree_count  h_t_sq_sum
# 0       9898827    45.83  13.0           1      169.00
# 1       9898828    45.83  13.0           1      169.00
# 2       9898971    45.83  13.0           1      169.00
# 3       9898972    45.83  13.0           1      169.00
# 4       9898972  1050.75  22.0           1      484.00
# ..          ...      ...   ...         ...         ...
# 173     9398791   130.51  13.3           1      176.89
# 174     9398792   130.51  13.3           1      176.89
# 175     9398619   356.22  20.9           1      436.81
# 176     9398620   356.22  20.9           1      436.81
# 177     9398787   356.22  20.9           1      436.81
#
# [178 rows x 5 columns]

# %%
Trees_RH_sum_5m = Trees_RH_sum.groupby(by='SHOTNUMBER').sum()

# %%
Trees_RH_sum_5m
# Out:
#              m_agb   h_t  tree_count  h_t_sq_sum
# SHOTNUMBER
# 9398619     356.22  20.9           1      436.81
# 9398620     356.22  20.9           1      436.81
# 9398787     356.22  20.9           1      436.81
# 9398791     130.51  13.3           1      176.89
# 9398792     130.51  13.3           1      176.89
# ...            ...   ...         ...         ...
# 9911014      31.56   8.0           1       64.00
# 9911015      31.56   8.0           1       64.00
# 9911016      31.56   8.0           1       64.00
# 9911018      24.68   8.9           1       79.21
# 9911200      31.56   8.0           1       64.00
#
# [104 rows x 4 columns]

# %%
Trees_RH_sum_5m
# Out:
#              m_agb   h_t  tree_count  h_t_sq_sum
# SHOTNUMBER
# 9398619     356.22  20.9           1      436.81
# 9398620     356.22  20.9           1      436.81
# 9398787     356.22  20.9           1      436.81
# 9398791     130.51  13.3           1      176.89
# 9398792     130.51  13.3           1      176.89
# ...            ...   ...         ...         ...
# 9911014      31.56   8.0           1       64.00
# 9911015      31.56   8.0           1       64.00
# 9911016      31.56   8.0           1       64.00
# 9911018      24.68   8.9           1       79.21
# 9911200      31.56   8.0           1       64.00
#
# [104 rows x 4 columns]

# %%
Trees_RH_sum_5m.to_csv(r'D:\Gabon_Lidar\DATA\pandas_csv\Trees_RH_sum_5m.csv')

# %%
Trees_RH_sum_5m =pd.read_csv(r'D:\Gabon_Lidar\DATA\pandas_csv\Trees_RH_sum_5m.csv')

# %%
Trees_RH_sum_5m
# Out:
#      SHOTNUMBER   m_agb   h_t  tree_count  h_t_sq_sum
# 0       9398619  356.22  20.9           1      436.81
# 1       9398620  356.22  20.9           1      436.81
# 2       9398787  356.22  20.9           1      436.81
# 3       9398791  130.51  13.3           1      176.89
# 4       9398792  130.51  13.3           1      176.89
# ..          ...     ...   ...         ...         ...
# 99      9911014   31.56   8.0           1       64.00
# 100     9911015   31.56   8.0           1       64.00
# 101     9911016   31.56   8.0           1       64.00
# 102     9911018   24.68   8.9           1       79.21
# 103     9911200   31.56   8.0           1       64.00
#
# [104 rows x 5 columns]

# %%
Trees_RH_sum_5m.columns = ['SHOTNUMBER', 'm_agb','h_t_sum','tree_count','h_t_sq_sum']

# %%
Trees_RH_sum_5m
# Out:
#      SHOTNUMBER   m_agb  h_t_sum  tree_count  h_t_sq_sum
# 0       9398619  356.22     20.9           1      436.81
# 1       9398620  356.22     20.9           1      436.81
# 2       9398787  356.22     20.9           1      436.81
# 3       9398791  130.51     13.3           1      176.89
# 4       9398792  130.51     13.3           1      176.89
# ..          ...     ...      ...         ...         ...
# 99      9911014   31.56      8.0           1       64.00
# 100     9911015   31.56      8.0           1       64.00
# 101     9911016   31.56      8.0           1       64.00
# 102     9911018   24.68      8.9           1       79.21
# 103     9911200   31.56      8.0           1       64.00
#
# [104 rows x 5 columns]

# %%
#MEAN

# %%
mean = ['SHOTNUMBER','h_t']

# %%
Trees_RH_Shot_5mean = Trees_LVIS_5m[mean]

# %%
Trees_RH_Shot_5mean = Trees_RH_Shot_5mean.groupby(by='SHOTNUMBER').mean()

# %%
Trees_RH_Shot_5mean.to_csv(r'D:\Gabon_Lidar\DATA\pandas_csv\Trees_RH_Shot_5mean.csv')

# %%
Trees_RH_Shot_5mean =pd.read_csv(r'D:\Gabon_Lidar\DATA\pandas_csv\Trees_RH_Shot_5mean.csv')

# %%
Trees_RH_Shot_5mean
# Out:
#      SHOTNUMBER   h_t
# 0       9398619  20.9
# 1       9398620  20.9
# 2       9398787  20.9
# 3       9398791  13.3
# 4       9398792  13.3
# ..          ...   ...
# 99      9911014   8.0
# 100     9911015   8.0
# 101     9911016   8.0
# 102     9911018   8.9
# 103     9911200   8.0
#
# [104 rows x 2 columns]

# %%
Trees_RH_Shot_5mean.columns = ['SHOTNUMBER','h_t_mean']

# %%
Trees_RH_Shot_5mean
# Out:
#      SHOTNUMBER  h_t_mean
# 0       9398619      20.9
# 1       9398620      20.9
# 2       9398787      20.9
# 3       9398791      13.3
# 4       9398792      13.3
# ..          ...       ...
# 99      9911014       8.0
# 100     9911015       8.0
# 101     9911016       8.0
# 102     9911018       8.9
# 103     9911200       8.0
#
# [104 rows x 2 columns]

# %%
#MAX

# %%
#Trees_LVIS_5m

# %%
Trees_LVIS_5m
# Out:
#      Join_Count     plot  subplot   tree_date        family  \
# 0             1   NASA02        1  2016-02-05    Annonaceae
# 1             1   NASA02        1  2016-02-05    Annonaceae
# 2             1   NASA02        1  2016-02-05    Annonaceae
# 3             1   NASA02        1  2016-02-05    Annonaceae
# 4             1   NASA02        1  2016-02-05  Vochysiaceae
# ..          ...      ...      ...         ...           ...
# 173           1  NASA21A        7  2016-02-11      Rutaceae
# 174           1  NASA21A        7  2016-02-11      Rutaceae
# 175           1  NASA21A       12  2016-02-11     Rubiaceae
# 176           1  NASA21A       12  2016-02-11     Rubiaceae
# 177           1  NASA21A       12  2016-02-11     Rubiaceae
#
#                   species       wsg  tree  stem   epsg  ...  CHANNEL_L1  \
# 0             Xylopia sp.  0.591038  6619     1  32632  ...           1
# 1             Xylopia sp.  0.591038  6619     1  32632  ...           1
# 2             Xylopia sp.  0.591038  6619     1  32632  ...           1
# 3             Xylopia sp.  0.591038  6619     1  32632  ...           1
# 4     Erismadelphus exsul  0.607100  6626     1  32632  ...           1
# ..                    ...       ...   ...   ...    ...  ...         ...
# 173  Zanthoxylum gilletii  0.686091  7054     1  32632  ...           1
# 174  Zanthoxylum gilletii  0.686091  7054     1  32632  ...           1
# 175            Hallea sp.  0.473429  7249     1  32632  ...           1
# 176            Hallea sp.  0.473429  7249     1  32632  ...           1
# 177            Hallea sp.  0.473429  7249     1  32632  ...           1
#
#      CHANNEL_ZG  CHANNEL_RH  POINT_X_2  POINT_Y_2  BUFF_DIST  ORIG_FID  \
# 0             1           1   9.318113   0.551334       12.5       578
# 1             1           1   9.318115   0.551240       12.5       579
# 2             1           1   9.318230   0.551239       12.5       582
# 3             1           1   9.318229   0.551334       12.5       583
# 4             1           1   9.318229   0.551334       12.5       583
# ..          ...         ...        ...        ...        ...       ...
# 173           1           1   9.381815   0.576620       12.5       290
# 174           1           1   9.381815   0.576526       12.5       291
# 175           1           1   9.381960   0.576966       12.5       281
# 176           1           1   9.381959   0.577061       12.5       282
# 177           1           1   9.381816   0.576996       12.5       286
#
#      Shape_Leng    Shape_Area                 geometry
# 0      0.000707  3.967866e-08  POINT (9.31817 0.55132)
# 1      0.000707  3.967857e-08  POINT (9.31817 0.55132)
# 2      0.000707  3.967862e-08  POINT (9.31817 0.55132)
# 3      0.000707  3.967866e-08  POINT (9.31817 0.55132)
# 4      0.000707  3.967866e-08  POINT (9.31832 0.55132)
# ..          ...           ...                      ...
# 173    0.000707  3.967891e-08  POINT (9.38185 0.57654)
# 174    0.000707  3.967891e-08  POINT (9.38185 0.57654)
# 175    0.000707  3.967881e-08  POINT (9.38192 0.57702)
# 176    0.000707  3.967873e-08  POINT (9.38192 0.57702)
# 177    0.000707  3.967890e-08  POINT (9.38192 0.57702)
#
# [178 rows x 73 columns]

# %%
max = ['SHOTNUMBER','RH10',
       'RH15', 'RH20', 'RH25', 'RH30', 'RH35', 'RH40', 'RH45', 'RH50', 'RH55',
       'RH60', 'RH65', 'RH70', 'RH75', 'RH80', 'RH85', 'RH90', 'RH95', 'RH96',
       'RH97', 'RH98', 'RH99', 'RH100','h_t']

# %%
Trees_RH_Shot_5max = Trees_LVIS_5m[max]

# %%
Trees_RH_Shot_5max = Trees_RH_Shot_5max.groupby(by='SHOTNUMBER').max()

# %%
Trees_RH_Shot_5max
# Out:
#             RH10   RH15   RH20   RH25   RH30   RH35   RH40   RH45   RH50  \
# SHOTNUMBER
# 9398619     0.37   1.57   2.77   4.19   5.99   7.64   8.91  10.11  11.68
# 9398620    -1.13  -0.60  -0.08   0.45   0.97   1.80   3.29   4.87   6.07
# 9398787    -0.38   0.30   1.20   4.49   7.94  10.26  11.99  13.63  15.06
# 9398791     8.54  10.42  11.61  12.44  13.04  13.64  14.16  14.69  15.28
# 9398792     5.17   7.19   8.92  10.12  10.94  11.61  12.14  12.66  13.11
# ...          ...    ...    ...    ...    ...    ...    ...    ...    ...
# 9911014    -3.30  -2.62  -2.10  -1.72  -1.35  -0.98  -0.68  -0.45  -0.15
# 9911015    -2.69  -2.02  -1.50  -1.05  -0.60  -0.22   0.23   0.60   1.05
# 9911016    -2.02  -1.50  -1.05  -0.60  -0.23   0.15   0.52   0.90   1.27
# 9911018    -1.73  -1.35  -1.13  -0.90  -0.68  -0.45  -0.23  -0.08   0.15
# 9911200    -3.52  -2.92  -2.47  -2.09  -1.72  -1.34  -1.05  -0.75  -0.45
#
#              RH55  ...   RH80   RH85   RH90   RH95   RH96   RH97   RH98  \
# SHOTNUMBER         ...
# 9398619     13.18  ...  16.93  17.60  18.35  19.40  19.70  20.00  20.45
# 9398620      6.89  ...  10.49  11.54  12.51  14.08  14.61  15.28  16.26
# 9398787     16.33  ...  20.23  20.90  21.50  22.25  22.40  22.63  22.92
# 9398791     15.96  ...  19.70  20.38  21.13  21.95  22.18  22.48  22.85
# 9398792     13.56  ...  16.33  17.16  18.06  19.33  19.63  20.08  20.60
# ...           ...  ...    ...    ...    ...    ...    ...    ...    ...
# 9911014      0.15  ...   1.72   2.17   2.84   4.11   4.86   6.36   8.01
# 9911015      1.50  ...   5.17   6.14   7.56   9.73  10.26  10.78  11.23
# 9911016      1.64  ...   4.41   5.31   6.14   7.11   7.41   7.71   8.23
# 9911018      0.37  ...   1.57   2.02   2.69   4.04   4.49   5.09   5.69
# 9911200     -0.22  ...   1.35   1.72   2.32   3.30   3.67   4.49   6.81
#
#              RH99  RH100   h_t
# SHOTNUMBER
# 9398619     21.12  22.55  20.9
# 9398620     17.53  20.00  20.9
# 9398787     23.30  24.12  20.9
# 9398791     23.52  25.55  13.3
# 9398792     21.35  22.92  13.3
# ...           ...    ...   ...
# 9911014     10.03  12.57   8.0
# 9911015     11.83  12.95   8.0
# 9911016     10.33  13.32   8.0
# 9911018      6.44   9.10   8.9
# 9911200     14.67  20.29   8.0
#
# [104 rows x 24 columns]

# %%
Trees_RH_Shot_5max.to_csv(r'D:\Gabon_Lidar\DATA\pandas_csv\Trees_RH_Shot_5max.csv')

# %%
Trees_RH_Shot_5max =pd.read_csv(r'D:\Gabon_Lidar\DATA\pandas_csv\Trees_RH_Shot_5max.csv')

# %%
Trees_RH_Shot_5max.columns = ['SHOTNUMBER','RH10',
       'RH15', 'RH20', 'RH25', 'RH30', 'RH35', 'RH40', 'RH45', 'RH50', 'RH55',
       'RH60', 'RH65', 'RH70', 'RH75', 'RH80', 'RH85', 'RH90', 'RH95', 'RH96',
       'RH97', 'RH98', 'RH99', 'RH100','h_t_max']

# %%
Trees_RH_Shot_5max.head()
# Out:
#    SHOTNUMBER  RH10   RH15   RH20   RH25   RH30   RH35   RH40   RH45   RH50  \
# 0     9398619  0.37   1.57   2.77   4.19   5.99   7.64   8.91  10.11  11.68
# 1     9398620 -1.13  -0.60  -0.08   0.45   0.97   1.80   3.29   4.87   6.07
# 2     9398787 -0.38   0.30   1.20   4.49   7.94  10.26  11.99  13.63  15.06
# 3     9398791  8.54  10.42  11.61  12.44  13.04  13.64  14.16  14.69  15.28
# 4     9398792  5.17   7.19   8.92  10.12  10.94  11.61  12.14  12.66  13.11
#
#    ...   RH80   RH85   RH90   RH95   RH96   RH97   RH98   RH99  RH100  h_t_max
# 0  ...  16.93  17.60  18.35  19.40  19.70  20.00  20.45  21.12  22.55     20.9
# 1  ...  10.49  11.54  12.51  14.08  14.61  15.28  16.26  17.53  20.00     20.9
# 2  ...  20.23  20.90  21.50  22.25  22.40  22.63  22.92  23.30  24.12     20.9
# 3  ...  19.70  20.38  21.13  21.95  22.18  22.48  22.85  23.52  25.55     13.3
# 4  ...  16.33  17.16  18.06  19.33  19.63  20.08  20.60  21.35  22.92     13.3
#
# [5 rows x 25 columns]

# %%
#Join Sum and MAX

# %%
 Trees_RH_Shot_5 = Trees_RH_Shot_5max.set_index('SHOTNUMBER').join( Trees_RH_sum_5m.set_index('SHOTNUMBER'))

# %%
 Trees_RH_Shot_5.to_csv(r'D:\Gabon_Lidar\DATA\pandas_csv\Trees_RH_Shot_5.csv')
# Out:
# ---------------------------------------------------------------------------
# PermissionError                           Traceback (most recent call last)
# <ipython-input-503-c9fc059fad95> in <module>
# ----> 1 Trees_RH_Shot_5.to_csv(r'D:\Gabon_Lidar\DATA\pandas_csv\Trees_RH_Shot_5.csv')
#
# ~\anaconda3\envs\G_H_GEDI\lib\site-packages\pandas\core\generic.py in to_csv(self, path_or_buf, sep, na_rep, float_format, columns, header, index, index_label, mode, encoding, compression, quoting, quotechar, line_terminator, chunksize, date_format, doublequote, escapechar, decimal, errors)
#    3165             decimal=decimal,
#    3166         )
# -> 3167         formatter.save()
#    3168
#    3169         if path_or_buf is None:
#
# ~\anaconda3\envs\G_H_GEDI\lib\site-packages\pandas\io\formats\csvs.py in save(self)
#     183             close = False
#     184         else:
# --> 185             f, handles = get_handle(
#     186                 self.path_or_buf,
#     187                 self.mode,
#
# ~\anaconda3\envs\G_H_GEDI\lib\site-packages\pandas\io\common.py in get_handle(path_or_buf, mode, encoding, compression, memory_map, is_text, errors)
#     491         if encoding:
#     492             # Encoding
# --> 493             f = open(path_or_buf, mode, encoding=encoding, errors=errors, newline="")
#     494         elif is_text:
#     495             # No explicit encoding
#
# PermissionError: [Errno 13] Permission denied: 'D:\\Gabon_Lidar\\DATA\\pandas_csv\\Trees_RH_Shot_5.csv'

# %%
 Trees_RH_Shot_5 =pd.read_csv(r'D:\Gabon_Lidar\DATA\pandas_csv\Trees_RH_Shot_5.csv')

# %%
 Trees_RH_Shot_5.columns

# %%
#Join MEAN

# %%
 Trees_RH_Shot_5 = Trees_RH_Shot_5.set_index('SHOTNUMBER').join(Trees_RH_Shot_5mean.set_index('SHOTNUMBER'))
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-505-2e1eb718498c> in <module>
# ----> 1 Trees_RH_Shot_5 = Trees_RH_Shot_5.set_index('SHOTNUMBER').join(Trees_RH_Shot_5mean.set_index('SHOTNUMBER'))
#
# ~\anaconda3\envs\G_H_GEDI\lib\site-packages\pandas\core\frame.py in set_index(self, keys, drop, append, inplace, verify_integrity)
#    4546
#    4547         if missing:
# -> 4548             raise KeyError(f"None of {missing} are in the columns")
#    4549
#    4550         if inplace:
#
# KeyError: "None of ['SHOTNUMBER'] are in the columns"

# %%
 Trees_RH_Shot_5
# Out:
#             RH10   RH15   RH20   RH25   RH30   RH35   RH40   RH45   RH50  \
# SHOTNUMBER
# 9398619     0.37   1.57   2.77   4.19   5.99   7.64   8.91  10.11  11.68
# 9398620    -1.13  -0.60  -0.08   0.45   0.97   1.80   3.29   4.87   6.07
# 9398787    -0.38   0.30   1.20   4.49   7.94  10.26  11.99  13.63  15.06
# 9398791     8.54  10.42  11.61  12.44  13.04  13.64  14.16  14.69  15.28
# 9398792     5.17   7.19   8.92  10.12  10.94  11.61  12.14  12.66  13.11
# ...          ...    ...    ...    ...    ...    ...    ...    ...    ...
# 9911014    -3.30  -2.62  -2.10  -1.72  -1.35  -0.98  -0.68  -0.45  -0.15
# 9911015    -2.69  -2.02  -1.50  -1.05  -0.60  -0.22   0.23   0.60   1.05
# 9911016    -2.02  -1.50  -1.05  -0.60  -0.23   0.15   0.52   0.90   1.27
# 9911018    -1.73  -1.35  -1.13  -0.90  -0.68  -0.45  -0.23  -0.08   0.15
# 9911200    -3.52  -2.92  -2.47  -2.09  -1.72  -1.34  -1.05  -0.75  -0.45
#
#              RH55  ...   RH96   RH97   RH98   RH99  RH100  h_t_max   m_agb  \
# SHOTNUMBER         ...
# 9398619     13.18  ...  19.70  20.00  20.45  21.12  22.55     20.9  356.22
# 9398620      6.89  ...  14.61  15.28  16.26  17.53  20.00     20.9  356.22
# 9398787     16.33  ...  22.40  22.63  22.92  23.30  24.12     20.9  356.22
# 9398791     15.96  ...  22.18  22.48  22.85  23.52  25.55     13.3  130.51
# 9398792     13.56  ...  19.63  20.08  20.60  21.35  22.92     13.3  130.51
# ...           ...  ...    ...    ...    ...    ...    ...      ...     ...
# 9911014      0.15  ...   4.86   6.36   8.01  10.03  12.57      8.0   31.56
# 9911015      1.50  ...  10.26  10.78  11.23  11.83  12.95      8.0   31.56
# 9911016      1.64  ...   7.41   7.71   8.23  10.33  13.32      8.0   31.56
# 9911018      0.37  ...   4.49   5.09   5.69   6.44   9.10      8.9   24.68
# 9911200     -0.22  ...   3.67   4.49   6.81  14.67  20.29      8.0   31.56
#
#             h_t_sum  tree_count  h_t_sq_sum
# SHOTNUMBER
# 9398619        20.9           1      436.81
# 9398620        20.9           1      436.81
# 9398787        20.9           1      436.81
# 9398791        13.3           1      176.89
# 9398792        13.3           1      176.89
# ...             ...         ...         ...
# 9911014         8.0           1       64.00
# 9911015         8.0           1       64.00
# 9911016         8.0           1       64.00
# 9911018         8.9           1       79.21
# 9911200         8.0           1       64.00
#
# [104 rows x 28 columns]

# %%
 Trees_RH_Shot_5.columns
# Out:
# Index(['RH10', 'RH15', 'RH20', 'RH25', 'RH30', 'RH35', 'RH40', 'RH45', 'RH50',
#        'RH55', 'RH60', 'RH65', 'RH70', 'RH75', 'RH80', 'RH85', 'RH90', 'RH95',
#        'RH96', 'RH97', 'RH98', 'RH99', 'RH100', 'h_t_max', 'm_agb', 'h_t_sum',
#        'tree_count', 'h_t_sq_sum'],
#       dtype='object')

# %%
#TreesRH13_22.columns

# %%
#matplotlib.pyplot.scatter(Trees_RH.m_agb,Trees_RH.ZG,color='r') 
matplotlib.pyplot.scatter(Trees_RH_Shot_5.m_agb,Trees_RH_Shot_5.RH25,color='orange') 
matplotlib.pyplot.scatter(Trees_RH_Shot_5.m_agb,Trees_RH_Shot_5.RH50,color='y')
matplotlib.pyplot.scatter(Trees_RH_Shot_5.m_agb,Trees_RH_Shot_5.RH75,color='g')
matplotlib.pyplot.scatter(Trees_RH_Shot_5.m_agb,Trees_RH_Shot_5.RH100,color='b')
matplotlib.pyplot.show()

# %%
matplotlib.pyplot.scatter(Trees_RH_Shot_5.m_agb,Trees_RH_Shot_5.RH25,color='orange')

# %%
matplotlib.pyplot.scatter(Trees_RH_Shot_5.m_agb,Trees_RH_Shot_5.RH50,color='y')

# %%
matplotlib.pyplot.scatter(Trees_RH_Shot_5.m_agb,Trees_RH_Shot_5.RH75,color='g')

# %%
matplotlib.pyplot.scatter(Trees_RH_Shot_5.m_agb,Trees_RH_Shot_5.RH100,color='b')

# %%
import statsmodels.api as sm

# %%
from sklearn import datasets ## imports datasets from scikit-learn

# %%
#http://seaborn.pydata.org/tutorial/regression.html

# %%
#This is where the chart come from

# %%
#Trees_RH_Shot_5

# %%
#PLOT 'NASA21A' - 5m - RH25

# %% [markdown]
# #### RH25

# %%
X = Trees_RH_Shot_5['m_agb']
y = Trees_RH_Shot_5["RH25"]

# Note the difference in argument order
model = sm.OLS(y, X).fit()
predictions = model.predict(X) # make the predictions by the model

# Print out the statistics
model.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                                  OLS Regression Results
# =======================================================================================
# Dep. Variable:                   RH25   R-squared (uncentered):                   0.379
# Model:                            OLS   Adj. R-squared (uncentered):              0.373
# Method:                 Least Squares   F-statistic:                              62.81
# Date:                Tue, 10 Nov 2020   Prob (F-statistic):                    2.82e-12
# Time:                        20:31:52   Log-Likelihood:                         -356.28
# No. Observations:                 104   AIC:                                      714.6
# Df Residuals:                     103   BIC:                                      717.2
# Df Model:                           1
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# m_agb          0.0004   5.24e-05      7.925      0.000       0.000       0.001
# ==============================================================================
# Omnibus:                       13.820   Durbin-Watson:                   0.886
# Prob(Omnibus):                  0.001   Jarque-Bera (JB):               15.987
# Skew:                           0.757   Prob(JB):                     0.000338
# Kurtosis:                       4.182   Cond. No.                         1.00
# ==============================================================================
#
# Notes:
# [1] R² is computed without centering (uncentered) since the model does not contain a constant.
# [2] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# """

# %%
sns.regplot(x='m_agb', y="RH25", data=Trees_RH_Shot_5);

# %% [markdown]
# #### RH50

# %%
X = Trees_RH_Shot_5['m_agb']
y = Trees_RH_Shot_5["RH50"]

# Note the difference in argument order
model = sm.OLS(y, X).fit()
predictions = model.predict(X) # make the predictions by the model

# Print out the statistics
model.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                                  OLS Regression Results
# =======================================================================================
# Dep. Variable:                   RH50   R-squared (uncentered):                   0.422
# Model:                            OLS   Adj. R-squared (uncentered):              0.417
# Method:                 Least Squares   F-statistic:                              75.35
# Date:                Tue, 10 Nov 2020   Prob (F-statistic):                    6.27e-14
# Time:                        20:31:52   Log-Likelihood:                         -396.30
# No. Observations:                 104   AIC:                                      794.6
# Df Residuals:                     103   BIC:                                      797.3
# Df Model:                           1
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# m_agb          0.0007    7.7e-05      8.680      0.000       0.001       0.001
# ==============================================================================
# Omnibus:                        6.217   Durbin-Watson:                   0.537
# Prob(Omnibus):                  0.045   Jarque-Bera (JB):                5.728
# Skew:                           0.557   Prob(JB):                       0.0570
# Kurtosis:                       3.287   Cond. No.                         1.00
# ==============================================================================
#
# Notes:
# [1] R² is computed without centering (uncentered) since the model does not contain a constant.
# [2] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# """

# %%
sns.regplot(x='m_agb', y="RH50", data=Trees_RH_Shot_5);

# %% [markdown]
# #### RH75

# %%
X = Trees_RH_Shot_5['m_agb']
y = Trees_RH_Shot_5["RH75"]

# Note the difference in argument order
model = sm.OLS(y, X).fit()
predictions = model.predict(X) # make the predictions by the model

# Print out the statistics
model.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                                  OLS Regression Results
# =======================================================================================
# Dep. Variable:                   RH75   R-squared (uncentered):                   0.365
# Model:                            OLS   Adj. R-squared (uncentered):              0.358
# Method:                 Least Squares   F-statistic:                              59.08
# Date:                Tue, 10 Nov 2020   Prob (F-statistic):                    9.26e-12
# Time:                        20:31:53   Log-Likelihood:                         -427.03
# No. Observations:                 104   AIC:                                      856.1
# Df Residuals:                     103   BIC:                                      858.7
# Df Model:                           1
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# m_agb          0.0008      0.000      7.686      0.000       0.001       0.001
# ==============================================================================
# Omnibus:                        2.521   Durbin-Watson:                   0.436
# Prob(Omnibus):                  0.283   Jarque-Bera (JB):                2.009
# Skew:                           0.326   Prob(JB):                        0.366
# Kurtosis:                       3.199   Cond. No.                         1.00
# ==============================================================================
#
# Notes:
# [1] R² is computed without centering (uncentered) since the model does not contain a constant.
# [2] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# """

# %%
sns.regplot(x='m_agb', y="RH75", data=Trees_RH_Shot_5);

# %% [markdown]
# ##### RH100

# %%
X = Trees_RH_Shot_5['m_agb']
y = Trees_RH_Shot_5["RH100"]

# Note the difference in argument order
model = sm.OLS(y, X).fit()
predictions = model.predict(X) # make the predictions by the model

# Print out the statistics
model.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                                  OLS Regression Results
# =======================================================================================
# Dep. Variable:                  RH100   R-squared (uncentered):                   0.261
# Model:                            OLS   Adj. R-squared (uncentered):              0.254
# Method:                 Least Squares   F-statistic:                              36.38
# Date:                Tue, 10 Nov 2020   Prob (F-statistic):                    2.57e-08
# Time:                        20:31:54   Log-Likelihood:                         -474.75
# No. Observations:                 104   AIC:                                      951.5
# Df Residuals:                     103   BIC:                                      954.2
# Df Model:                           1
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# m_agb          0.0010      0.000      6.032      0.000       0.001       0.001
# ==============================================================================
# Omnibus:                        5.325   Durbin-Watson:                   0.284
# Prob(Omnibus):                  0.070   Jarque-Bera (JB):                5.078
# Skew:                          -0.371   Prob(JB):                       0.0789
# Kurtosis:                       3.788   Cond. No.                         1.00
# ==============================================================================
#
# Notes:
# [1] R² is computed without centering (uncentered) since the model does not contain a constant.
# [2] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# """

# %%
sns.regplot(x='m_agb', y="RH100", data=Trees_RH_Shot_5);

# %%
## Quadratic canopy profile

# %%
Trees_RH_Shot_5['Canopy_Profile'] = (Trees_RH_Shot_5['h_t_sq_sum'] / Trees_RH_Shot_5['tree_count'] )**.5

# %%
Trees_RH_Shot_5.head()
# Out:
#             RH10   RH15   RH20   RH25   RH30   RH35   RH40   RH45   RH50  \
# SHOTNUMBER
# 9398619     0.37   1.57   2.77   4.19   5.99   7.64   8.91  10.11  11.68
# 9398620    -1.13  -0.60  -0.08   0.45   0.97   1.80   3.29   4.87   6.07
# 9398787    -0.38   0.30   1.20   4.49   7.94  10.26  11.99  13.63  15.06
# 9398791     8.54  10.42  11.61  12.44  13.04  13.64  14.16  14.69  15.28
# 9398792     5.17   7.19   8.92  10.12  10.94  11.61  12.14  12.66  13.11
#
#              RH55  ...   RH97   RH98   RH99  RH100  h_t_max   m_agb  h_t_sum  \
# SHOTNUMBER         ...
# 9398619     13.18  ...  20.00  20.45  21.12  22.55     20.9  356.22     20.9
# 9398620      6.89  ...  15.28  16.26  17.53  20.00     20.9  356.22     20.9
# 9398787     16.33  ...  22.63  22.92  23.30  24.12     20.9  356.22     20.9
# 9398791     15.96  ...  22.48  22.85  23.52  25.55     13.3  130.51     13.3
# 9398792     13.56  ...  20.08  20.60  21.35  22.92     13.3  130.51     13.3
#
#             tree_count  h_t_sq_sum  Canopy_Profile
# SHOTNUMBER
# 9398619              1      436.81            20.9
# 9398620              1      436.81            20.9
# 9398787              1      436.81            20.9
# 9398791              1      176.89            13.3
# 9398792              1      176.89            13.3
#
# [5 rows x 29 columns]

# %%
Trees_RH_Shot_5.to_csv(r'D:\Gabon_Lidar\DATA\pandas_csv\Trees_RH_Shot_125_CP_h_t.csv')
Trees_RH_Shot_5 =pd.read_csv(r'D:\Gabon_Lidar\DATA\pandas_csv\Trees_RH_Shot_125_CP_h_t.csv')
# Out:
# ---------------------------------------------------------------------------
# PermissionError                           Traceback (most recent call last)
# <ipython-input-531-0baeb237b6db> in <module>
# ----> 1 Trees_RH_Shot_5.to_csv(r'D:\Gabon_Lidar\DATA\pandas_csv\Trees_RH_Shot_125_CP_h_t.csv')
#       2 Trees_RH_Shot_5 =pd.read_csv(r'D:\Gabon_Lidar\DATA\pandas_csv\Trees_RH_Shot_125_CP_h_t.csv')
#
# ~\anaconda3\envs\G_H_GEDI\lib\site-packages\pandas\core\generic.py in to_csv(self, path_or_buf, sep, na_rep, float_format, columns, header, index, index_label, mode, encoding, compression, quoting, quotechar, line_terminator, chunksize, date_format, doublequote, escapechar, decimal, errors)
#    3165             decimal=decimal,
#    3166         )
# -> 3167         formatter.save()
#    3168
#    3169         if path_or_buf is None:
#
# ~\anaconda3\envs\G_H_GEDI\lib\site-packages\pandas\io\formats\csvs.py in save(self)
#     183             close = False
#     184         else:
# --> 185             f, handles = get_handle(
#     186                 self.path_or_buf,
#     187                 self.mode,
#
# ~\anaconda3\envs\G_H_GEDI\lib\site-packages\pandas\io\common.py in get_handle(path_or_buf, mode, encoding, compression, memory_map, is_text, errors)
#     491         if encoding:
#     492             # Encoding
# --> 493             f = open(path_or_buf, mode, encoding=encoding, errors=errors, newline="")
#     494         elif is_text:
#     495             # No explicit encoding
#
# PermissionError: [Errno 13] Permission denied: 'D:\\Gabon_Lidar\\DATA\\pandas_csv\\Trees_RH_Shot_125_CP_h_t.csv'

# %%
## Quadratic canopy profile

# %%
SQRT((sum(h_t**2)/count())
# Out:
#   File "<ipython-input-453-5586866b43d5>", line 1
#     SQRT((sum(h_t**2)/count())
#                               ^
# SyntaxError: unexpected EOF while parsing

# %% [markdown]
# **SLICER data collection and processing**

# %% [markdown]
# SLICER data were collected from airborne platforms at
# the temperate coniferous, boreal coniferous and temperate
# deciduous sites in September 1995, July 1996 and September
# 1995, respectively. Lidar waveforms were collected over contiguous 10-m footprints for five lidar waveforms across the
# sampling swath. To estimate canopy height profiles (CHPs,
# the vertical distribution of foliage and woody surfaces) from
# the raw SLICER waveforms, Harding et al. (2001) adapted the
# transformation method developed by MacArthur & Horn
# (1969). The resulting CHPs serve as a common measurement
# of forest canopy structure at the three sites. One key factor in
# the CHP algorithm is a coefficient defined as the ratio of the
# average reflectance (at nadir) of the ground and canopy at the
# laser wavelength (1064 nanometres). For the temperate
# deciduous and temperate coniferous sites, the ratio of ground
# and canopy reflectance is assumed to be 2.0. Use of this
# assumption has been supported by fieldwork comparing lidar
# estimates and field measurements of canopy cover at these sites
# (Lefsky, 1997; Means et al., 1999). At the boreal coniferous
# site, the existence of a high ground-level cover of herbaceous
# moss and fern species and a small dataset of coincident lidar
# and field measurements of cover imply that this ratio should
# be close to 1.0, the value used in calculations for this site.
#     Canopy structure indices used in this study were calculated
# for each plot from CHPs following the methods of Lefsky
# et al. (1999a). A variety of indices were selected from our
# previous work in the temperate sites and preliminary work
# with the boreal coniferous dataset. The indices are canopy
# cover, mean canopy height (MCH, the average height of the
# waveforms associated with a plot), maximum height (the
# maximum height of the same set of waveforms), MCH squared,
# and the mean canopy profile height, defined as:
# Mean canopy profile height =
# where: CHP(i) is the normalized canopy height profile at
# height i, and h is the maximum height of the canopy.
# The quadratic canopy profile height is defined as:
# Quadratic canopy profile height =
# In addition to considering the height and canopy cover
# variables separately, the products of canopy cover and each of
# the height indices were also considered, as suggested by our
# initial experience with the boreal site. At the eastern deciduous
# site, 64 plots with lidar-estimated CHPs were supplemented
# with 48 plots with field-measured CHPs, to incorporate a
# greater range of stand conditions. Treating these two datasets
# as equivalent for the purposes of estimating above-ground
# biomass is supported by the findings of Lefsky et al. (1999a).
# Measurements of mean canopy height are not available
# for the field measured CHPs; a regression between quadratic
# mean canopy height and mean canopy surface height was
# developed using those plots with lidar measurements, and
# then applied to predict mean canopy height. Scatterplots of
# variable combinations were examined to ensure linearity.

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
Trees_RH_Shot_5.columns
# Out:
# Index(['RH10', 'RH15', 'RH20', 'RH25', 'RH30', 'RH35', 'RH40', 'RH45', 'RH50',
#        'RH55', 'RH60', 'RH65', 'RH70', 'RH75', 'RH80', 'RH85', 'RH90', 'RH95',
#        'RH96', 'RH97', 'RH98', 'RH99', 'RH100', 'h_t_modmax', 'm_agb',
#        'h_t_mod', 'h_t_sq_sum', 'h_t_modmean'],
#       dtype='object')

# %%
Trees_RH_Shot_5.h_t_modmean
# Out:
# SHOTNUMBER
# 9361768    11.941892
# 9361769    11.830303
# 9361773    15.290909
# 9361774    15.830000
# 9361775    14.730000
#              ...
# 9362444    13.849444
# 9362445    16.163333
# 9362446    17.427917
# 9362447    14.116154
# 9362448    13.459444
# Name: h_t_modmean, Length: 63, dtype: float64

# %%
(h_t_modmean**2)/

# %%
Trees_RH_Shot_5.h_t_modmax
# Out:
# SHOTNUMBER
# 9361768    16.43
# 9361769    16.32
# 9361773    19.06
# 9361774    19.06
# 9361775    17.38
#            ...
# 9362444    29.94
# 9362445    36.80
# 9362446    36.80
# 9362447    23.74
# 9362448    23.74
# Name: h_t_modmax, Length: 63, dtype: float64

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
import seaborn as sns

# %%
sns.regplot(x='m_agb', y="RH100", data=Trees_RH_Shot_5);

# %%
#

# %%
sns.regplot(x='Trees_RH_Shot_5['m_agb']', y='Trees_RH_Shot_5["RH100"]', data=motif)
# Out:
#   File "<ipython-input-92-bb9eba48c3b2>", line 1
#     sns.regplot(x='Trees_RH_Shot_5['m_agb']', y='Trees_RH_Shot_5["RH100"]', data=motif)
#                                     ^
# SyntaxError: invalid syntax

# %%
Trees_RH_Shot_5.plot()
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# ~\anaconda3\envs\G_H_GEDI\lib\site-packages\pandas\core\indexes\base.py in get_loc(self, key, method, tolerance)
#    2888             try:
# -> 2889                 return self._engine.get_loc(casted_key)
#    2890             except KeyError as err:
#
# pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'Trees_RH_Shot_5["m_agb"]'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# <ipython-input-89-500743b00f42> in <module>
# ----> 1 Trees_RH_Shot_5.plot(y = 'Trees_RH_Shot_5["RH100"]',x =  'Trees_RH_Shot_5["m_agb"]')
#
# ~\anaconda3\envs\G_H_GEDI\lib\site-packages\pandas\plotting\_core.py in __call__(self, *args, **kwargs)
#     912                 if is_integer(x) and not data.columns.holds_integer():
#     913                     x = data_cols[x]
# --> 914                 elif not isinstance(data[x], ABCSeries):
#     915                     raise ValueError("x must be a label or position")
#     916                 data = data.set_index(x)
#
# ~\anaconda3\envs\G_H_GEDI\lib\site-packages\pandas\core\frame.py in __getitem__(self, key)
#    2900             if self.columns.nlevels > 1:
#    2901                 return self._getitem_multilevel(key)
# -> 2902             indexer = self.columns.get_loc(key)
#    2903             if is_integer(indexer):
#    2904                 indexer = [indexer]
#
# ~\anaconda3\envs\G_H_GEDI\lib\site-packages\pandas\core\indexes\base.py in get_loc(self, key, method, tolerance)
#    2889                 return self._engine.get_loc(casted_key)
#    2890             except KeyError as err:
# -> 2891                 raise KeyError(key) from err
#    2892
#    2893         if tolerance is not None:
#
# KeyError: 'Trees_RH_Shot_5["m_agb"]'

# %%
## Without a constant

import statsmodels.api as sm

X = df["RM"]
y = target["RH25"]

# Note the difference in argument order
model = sm.OLS(y, X).fit()
predictions = model.predict(X) # make the predictions by the model

# Print out the statistics
model.summary()
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# ~\anaconda3\envs\G_H_GEDI\lib\site-packages\pandas\core\indexes\base.py in get_loc(self, key, method, tolerance)
#    2888             try:
# -> 2889                 return self._engine.get_loc(casted_key)
#    2890             except KeyError as err:
#
# pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'RH25'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# <ipython-input-8-767bb31f2df0> in <module>
#       4
#       5 X = df["RM"]
# ----> 6 y = target["RH25"]
#       7
#       8 # Note the difference in argument order
#
# ~\anaconda3\envs\G_H_GEDI\lib\site-packages\pandas\core\frame.py in __getitem__(self, key)
#    2900             if self.columns.nlevels > 1:
#    2901                 return self._getitem_multilevel(key)
# -> 2902             indexer = self.columns.get_loc(key)
#    2903             if is_integer(indexer):
#    2904                 indexer = [indexer]
#
# ~\anaconda3\envs\G_H_GEDI\lib\site-packages\pandas\core\indexes\base.py in get_loc(self, key, method, tolerance)
#    2889                 return self._engine.get_loc(casted_key)
#    2890             except KeyError as err:
# -> 2891                 raise KeyError(key) from err
#    2892
#    2893         if tolerance is not None:
#
# KeyError: 'RH25'
